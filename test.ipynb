# %%
from RAG_Chain import *
rag_chain = RAG_Chain(rfp_path="data/rfp/project_4", verbose=True)
rag_chain.get_context()
# Out:
# Extracting company background..
#
# Extracting company project experience..
#
# Extracting company product & services..
#
# Extracting company team members..
#
# Extracting RFP background..
#
# Extracting RFP objectives..
#
# Extracting RFP scopes..
# ...

# %%
general_methodology_and_implementation_prompt = rag_chain.write_general_methodology_and_implementation()
print(general_methodology_and_implementation_prompt)
# Out:
# Writing general methodology and implementation..
# time info:
# # Methodology & Implementation Plan
#
# ## 1. Methodology
#
# Our approach to executing the project for the PrivateHealth.gov.au website will be grounded in industry best practices, ensuring a comprehensive, user-centered, and compliant solution. The methodology will encompass the following key principles:
#
# ### 1.1 Agile Development
# We will adopt an Agile development methodology, allowing for iterative progress, flexibility, and responsiveness to changes. This approach will facilitate regular feedback loops with stakeholders, ensuring that the evolving needs of users and compliance requirements are met effectively.
#
# ### 1.2 User-Centric Design
# The design and functionality of the website will prioritize user experience. We will conduct user research and usability testing to understand consumer needs, ensuring that the website is intuitive, accessible, and meets the expectations of over 1 million annual users.
#
# ...

# %%
rag_chain.extract_company_overview()
# Out:
# Extracting company overview..
# This doesn't provide any relevant information.
# ---------------------
# The company profile highlights several relevant capabilities that align with the requirements of the PrivateHealth.gov.au project:
#
# 1. **Solution and Enterprise Architecture**: The company specializes in designing AI solutions that integrate seamlessly within broader ecosystems, which is essential for the management and support of the PrivateHealth.gov.au website.
#
# 2. **Cloud AI Solutions**: Expertise in major cloud platforms (AWS, GCP, Azure) indicates the ability to provide reliable hosting and maintenance services for the website.
#
# 3. **Security and Reliability**: The emphasis on DevSecOps practices ensures that security measures are integrated throughout the development lifecycle, which is crucial for maintaining compliance with cyber security requirements outlined in the RFP.
#
# ...
