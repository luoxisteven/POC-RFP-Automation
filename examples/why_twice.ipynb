# %%
from RAG_Chain import *
rag_chain = RAG_Chain()
only_summary, twice = rag_chain.extract_RFP_scopes()
# Out:
# /Users/stev/opt/anaconda3/lib/python3.9/importlib/__init__.py:127: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   return _bootstrap._gcd_import(name[level:], package, level)
# /Users/stev/opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# ### Only Once (With General Chunk summary)
#
# Tends to generate general answer without giving correct answer.

# %%
print(only_summary)
# Out:
# The Request for Proposal (RFP) outlines the following key scopes of work and deliverables for the development of the MAP System for the Fair Work Commission:
#
# 1. **Project Management**:
#    - Utilize MS Teams for project management.
#    - Provide a dedicated Project Manager as the main contact.
#    - Ensure experienced resources are provided.
#
# 2. **Technical Compliance**:
#    - Adhere to the Privacy Act 1988 and Australian Privacy Principles.
#    - Follow the Australian Government Information Security Manual (ISM) and the Commission's security policies.
#
# 3. **Collaboration and Change Management**:
#    - Collaborate with the Change Advisory Board (CAB) for timely proposal submissions.
#
# 4. **COVID-19 Considerations**:
#    - Conduct work offsite and hold meetings via teleconference.
#    - Advise on business continuity arrangements related to COVID-19.
#
# 5. **Support and Compliance**:
#    - Provide support SLAs for each location.
# ...

# %% [markdown]
# ### Twice (with both General Context and Heading Locating)
#
#     Provide more details

# %%
print(twice)
# Out:
# The RFP outlines the development of the MAP System for the Fair Work Commission, focusing on several key scopes of work and deliverables:
#
# 1. **Award Updates Management**: Implement a system for managing updates to awards, ensuring version control and up-to-date templates.
#
# 2. **Database Utilization**: Use the existing 2018 database for wage rates and allowances, enabling wage increases and generating Word documents.
#
# 3. **User-Friendly Solutions**: Propose solutions that streamline the system, allowing easy updates without complex coding.
#
# 4. **Integration Maintenance**: Maintain integration with services like the MAPD API for querying awards and rates.
#
# 5. **Document Management**: Manage document lifecycles, including metadata and properties for award-related data.
#
# 6. **Formula Library**: Develop a library for storing and calculating rates of pay for each award.
#
# 7. **Document Templating**: Enable modification of award templates without coding skills.
#
# ...
