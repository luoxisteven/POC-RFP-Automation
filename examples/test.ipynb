# %%
from RAG_Chain import *
rag_chain = RAG_Chain()
# Out:
# /Users/stev/opt/anaconda3/lib/python3.9/importlib/__init__.py:127: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   return _bootstrap._gcd_import(name[level:], package, level)
# /Users/stev/opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
rag_chain.extract_RFP_background()
# Out:
# "The Fair Work Commission, established by the Fair Work Act 2009, is Australia's national workplace relations tribunal responsible for resolving workplace issues, setting the national minimum wage, approving enterprise agreements, and regulating registered organisations like unions. It oversees 155 modern awards that define minimum wages, penalty rates, allowances, and working conditions across various industries. The Commission conducts an Annual Wage Review, with decisions typically released in the first week of June.\n\nSince 2018, the Commission has developed a database and platform containing unique wage rates and historical data for awards dating back to 2015. This platform facilitates wage increases based on Commission decisions and generates Word documents using embedded coding, which requires significant programming knowledge, making it less user-friendly. The current system for updating rates in awards needs improvement to streamline operations. The project aims to explore 
# ...

# %%
print(rag_chain.extract_RFP_objectives())
# Out:
# The project aims to enhance the Fair Work Commission Modern Awards Database by:
#
# 1. Establishing a document management system for overseeing document lifecycles.
# 2. Creating a formula library for pay rate calculations.
# 3. Implementing a user-friendly document templating solution.
# 4. Improving data validation processes for accuracy and compliance.
# 5. Leveraging Microsoft technologies for streamlined management and publishing.
# 6. Creating a centralized repository for award-related information to enhance operational efficiency and data integrity.
#
# ...

# %%
print(rag_chain.extract_RFP_scopes())
# Out:
# The Request for Proposal (RFP) outlines the following key scopes of work and deliverables for the development of the MAP System for the Fair Work Commission:
#
# 1. **Annual Wage Review Participation**: Engage in the Annual Wage Review process and contribute to the formulation of decisions.
# 2. **Formula Library Development**: Create a library for storing and calculating pay rates for modern awards.
# 3. **Document Templating Solution**: Develop a user-friendly solution for modifying award templates without coding.
# 4. **Compatibility and Environment Setup**: Align with Microsoft Cloud applications and establish necessary environments using Microsoft 365, Dynamics, and Power Platforms.
# 5. **Data Import and Support Model**: Import existing data and provide a support model for service continuity.
# 6. **Requirements Documentation and User Acceptance**: Adhere to specified requirements and develop user acceptance criteria.
# ...

# %%
print(rag_chain.extract_company_background())
# Out:
# **Company Background**
#
# AddAxis.AI is a leading AI company with over seven years of experience in the Australia and JAPAC regions, specializing in advanced AI solutions. The team consists of over 20 experts in AI research, data science, and engineering, with a focus on natural language processing, computer vision, reinforcement learning, and AI ethics. The company excels in utilizing various AI/ML platforms, particularly Google’s AI tools, to transform complex data into actionable insights. Recognized as one of the top ten machine learning companies in the Asia-Pacific region, AddAxis.AI is committed to aligning AI technology with business outcomes to drive innovation and growth.

# %%
print(rag_chain.extract_company_project_experience())
# Out:
# **Project Experience Summary:**
#
# 1. **Inventory Optimisation at Amazon.com**
#    - **Objective:** Recover lost inventory.
#    - **Outcome:** Innovated processes, recovering millions in lost assets.
#
# 2. **Golang and ChatGPT Integration**
#    - **Technologies:** Golang, ChatGPT.
#    - **Outcome:** Enhanced system capabilities.
#
# 3. **WHMCS Integration**
#    - **Objective:** Streamline operations.
#    - **Outcome:** Improved service delivery.
#
# 4. **WordPress Plugin Development**
#    - **Objective:** Enhance functionality.
#    - **Outcome:** Added features for users.
#
# 5. **IoT Architectural Design in Australia**
#    - **Objective:** Lead IoT design efforts.
#    - **Outcome:** Established a robust architectural framework.
#
# 6. **AI Solutions for Bureau of Meteorology**
#    - **Objective:** Enhance meteorological applications.
#    - **Outcome:** Developed innovative weather data analysis solutions.
#
# ...

# %%
print(rag_chain.extract_company_product_services())
# Out:
# **Product & Services Summary:**
#
# 1. **AI Solutions Design**: Comprehensive design of AI solutions that integrate seamlessly within existing ecosystems, focusing on ethical AI development.
#
# 2. **Cloud AI Expertise**: Proficient in major cloud platforms (AWS, GCP, Azure) for deploying AI solutions.
#
# 3. **Data Warehousing**: Expertise in Snowflake, BigQuery, and Redshift for optimized data storage and retrieval.
#
# 4. **Reporting Tools**: Skilled in Microsoft Power BI, Google Looker, and AWS Quicksight for effective data reporting.
#
# 5. **Security and Reliability**: Emphasis on DevSecOps practices, utilizing infrastructure as code and GitOps for secure deployments.
#
# 6. **API Design and Management**: Development and management of APIs for AI integrations.
#
# 7. **MLOps**: Streamlined deployment, management, and monitoring of machine learning models, enhancing collaboration among teams.
#
# ...

# %%
print(rag_chain.extract_company_team_members())
# Out:
# ### Team Members Summary
#
# 1. **Dr. Alex Antic - Advisor**
#    - **Experience:** 18+ years in Advanced Analytics, Machine Learning, AI, Mathematics, and Statistics.
#    - **Domains:** Government, Asset Management, Insurance, Banking, and Consulting.
#    - **Achievements:** Top 5 Analytics Leaders in Australia (IAPA, 2021).
#    - **Qualifications:** Ph.D. in Applied Mathematics; double degree in Mathematics and Computer Science.
#
# 2. **Mark Ridley - Advisor**
#    - **Experience:** Independent director with expertise in governance, risk, and financial management.
#    - **Current Roles:** Chair of audit & risk committees for the Department of Foreign Affairs and Trade and Australian Signals Directorate.
#    - **Background:** Former senior partner at PricewaterhouseCoopers.
#
# 3. **Timothy Scholes - Founder**
#    - **Experience:** Former roles at Macquarie Bank, Commbank, Qantas Insurance, AWS; founder of tech start-ups.
# ...

# %%
company_general_context = rag_chain.extract_company_general_context()
print(company_general_context)
print("---------company_general_context-------------")
# Out:
# AddAxis.AI is a leading AI company specializing in advanced AI solutions across various industries. Their mission is to transform complex data into actionable insights, enhancing organizational agility, security, and innovation. Recognized as one of the top ten machine learning companies in the Asia-Pacific region, they have over seven years of experience in Australia and the JAPAC region. The team comprises more than 20 experts in natural language processing, computer vision, reinforcement learning, and AI ethics. They utilize AI/ML platforms like AWS, GCP, Azure, and OpenAI, with a focus on Google's AI tools, and are known for delivering projects on time, within scope, and on budget.
#
# **Project Experience Summary:**
#
# 1. **Inventory Optimisation at Amazon.com**:
#    - **Objective**: Locate millions in lost inventory.
#    - **Outcome**: Innovated inventory optimisation.
#
# 2. **Integration Projects**:
#    - **Technologies**: Golang, ChatGPT, WHMCS, WordPress.
# ...

# %%
company_local_context = rag_chain.extract_company_local_context("How to perform cybersecurity")
print(company_local_context)
print("---------company_local_context-------------")
# Out:
# We help integrate security practices into your DevOps process, ensuring security is a shared responsibility throughout the software development lifecycle. The primary goal here is to embed security measures early in the development cycle rather than treating it as a separate or final step.
#
# Benefits:
#
# Early Detection of Vulnerabilities
# The provided text mentions the following information related to performing cybersecurity:
#
# - Early Detection of Vulnerabilities: Incorporating security from the start to identify and address vulnerabilities earlier in the development process.
# - Automating security testing and continuous integration to streamline the development process.
# - Fostering collaboration between development, operations, and security teams to create a shared responsibility for security.
# - Delivering continuous security assessments and automated monitoring to ensure security measures are always up-to-date and proactively address new threats and vulnerabilities.
# ...

# %%
rfp_general_context = rag_chain.extract_RFP_general_context()
print(rfp_general_context)
print("---------RFP_general_context-------------")
# Out:
# **Background Summary:**
#
# The Fair Work Commission, established by the Fair Work Act 2009, is Australia's national workplace relations tribunal and regulator of registered organisations. It assists in resolving workplace issues, sets the national minimum wage, approves enterprise agreements, and creates modern awards. The Commission also oversees unions and employer organisations. This context is crucial for understanding the scope and requirements of the MAP System 2024 project.
#
# ### Summary of Objectives for the Request for Proposal (RFP)
#
# #### System Implementation and Integration
# 1. **New Implementation**: Develop a new platform separate from the existing system for updating rates in Awards.
# 2. **Streamline Activities**: Simplify team activities with a new perspective.
# 3. **User-Friendly Solutions**: Replace the current system with user-friendly solutions that do not require programming knowledge.
# ...

# %%
rfp_local_context = rag_chain.extract_RFP_local_context("How to perform cybersecurity")
print(rfp_local_context)
print("---------RFP_local_context-------------")
# Out:
# The technical solution should apply Australian Government Information Security Manual (ISM).
# The provided text contains the following information related to cybersecurity:
#
# REQ-008
# Non-Functional - Security
# Mandatory
# Role based access controls
# High
# ICT
# Should have ability to set roles based access controls based on segregation of duties and ensure access levels are based on 'least privilege' to ensure use is within the scope of the users' roles/responsibilities
#
# REQ-009
# Non-Functional - Security
# Mandatory
# Security mechanisms for data transmission
# High
# ICT
# Must support industry standard security mechanisms for data transmission
#
# REQ-010
# Non-Functional - Security
# Mandatory
# Legal and regulatory requirements
# High
# ICT
# Must comply with all Australian legal and regulatory requirements
# The provided text includes the following information related to performing cybersecurity:
#
# ...

# %%
answer = rag_chain.query_answering("How to perform cybersecurity", company_general_context, company_local_context, rfp_general_context, rfp_local_context)
print(answer)
print("answer")
# Out:
# To perform cybersecurity effectively for the Fair Work Commission (FWC) in the context of the MAP System 2024 project, AddAxis.AI should integrate its expertise and align with the specific requirements outlined in the RFP. Here’s a comprehensive approach:
#
# ### 1. **Role-Based Access Controls (RBAC)**
#    - **Implementation**: Configure RBAC to ensure access levels are based on the principle of 'least privilege,' aligning with REQ-008 and REQ-015.
#    - **Management**: Regularly review and update roles to reflect changes in user responsibilities and ensure compliance with segregation of duties.
#
# ### 2. **Data Encryption**
#    - **In Transit**: Use ASD Approved Cryptographic Protocols (AACPs) to encrypt data during transmission (REQ-016).
#    - **At Rest**: Implement ASD Approved Cryptographic Algorithms (AACAs) to secure data stored within the system (REQ-017).
#
# ### 3. **Compliance with Legal and Regulatory Requirements**
# ...
