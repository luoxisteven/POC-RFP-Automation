# %%
from RAG_Chain import *
rag_chain = RAG_Chain(
# Out:
# /Users/stev/opt/anaconda3/lib/python3.9/site-packages/langchain_ollama/__init__.py:4: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   from langchain_ollama.embeddings import OllamaEmbeddings

# %% [markdown]
# ### **General Context for RFP**
# -----

# %%
print(rag_chain.extract_RFP_general_context())
# Out:
# The Request for Proposal (RFP) is issued by AGENTS, an organization that provides Housing Services, Community Action, and Financial Stability. Their services include home weatherization, essential home repair, homeless services, energy assistance, and financial education, all delivered respectfully. AGENTS aims to replace its outdated data system, which has been in use for over 30 years and is based on the unsupported FoxPro platform. The current system has managed client counts effectively but faces challenges due to program expansion, resulting in issues like duplicate data entry, limited integration with modern systems, and difficulties accessing historical data. The new system must enhance user experience, support over 150 users, and enable data sharing with partners through APIs or other methods. It must also comply with security standards for Personally Identifiable Information (PII), including the California Consumer Protection Act (CCPA) and HIPAA for medical data. The RFP seeks proposals from software development and system integrator service providers to meet these requirements and project goals, ultimately selecting one or more vendors for a contracting phase to finalize pricing and scope of work.
#
# The Request for Proposal (RFP) aims to establish a new enterprise data system to replace the outdated FoxPro system, focusing on the following key objectives:
#
# 1. **System Replacement and Enhancement**: Implement a new system that improves user experience and supports future growth.
# 2. **User Accommodation**: Support over 150 users.
# 3. **Data Sharing Capabilities**: Enable data sharing with partners via APIs or user-friendly methods.
# 4. **Compliance with Security Standards**: Adhere to security standards for Personally Identifiable Information (PII), including CCPA and HIPAA.
# 5. **Flexibility for Growth**: Allow responsiveness to local needs and support new programs and services.
# 6. **Data Integration and Reporting**: Enhance integration with third-party systems and improve historical data reporting.
# 7. **Reduction of Workarounds**: Minimize duplicate data entry and reliance on Excel spreadsheets.
# 8. **Training Program Development**: Establish a "Train the Trainer" methodology for effective knowledge transfer.
# 9. **Documentation Creation**: Develop comprehensive manuals and user guides for system features.
# 10. **Licensing Acquisition**: Secure software licenses for testing and training environments.
# 11. **Standardized Deliverables**: Ensure technical deliverables follow a standardized format.
# 12. **System Requirements Implementation**: Meet management functions like Purchase Order, Budget, Grant, Contract, and Inventory Management.
# 13. **Client Intake Features**: Include geo-location and custom income calculations in client intake.
# 14. **Reporting and Document Generation**: Create a report dashboard and capabilities for mail merge and customizable forms.
# 15. **Timesheet Management**: Develop a timesheet system for various employee types and project labor cost tracking.
# 16. **Integration and Compatibility**: Ensure compatibility with existing systems like Blackbaud Financial Edge.
# 17. **Regulatory Compliance**: Adapt to state and federal regulations.
# 18. **Client and Emergency Management**: Implement effective client intake and management for emergencies.
# 19. **Vendor and Volunteer Management**: Streamline vendor intake and enhance volunteer coordination.
# 20. **Project Management Structure**: Establish a structured project management approach with regular status updates.
# 21. **Warranty and Support**: Provide warranty and support for customized software during working hours.
#
# Overall, the RFP seeks to create a comprehensive, flexible, and user-friendly system that enhances operational efficiency, ensures compliance, and improves data management and reporting capabilities within AGENTS.
#
# ### Summary of Scopes from the RFP Document:
#
# 1. **System Replacement and Enhancement**:
#    - Replace the legacy FoxPro system and improve user experience for growth and service expansion.
#
# 2. **User Accommodation**:
#    - Support a user base of over 150 individuals.
#
# 3. **Data Sharing Capabilities**:
#    - Enable data sharing with partners via APIs or user-friendly methods.
#
# 4. **Compliance with Security Standards**:
#    - Ensure data storage and exchange meet security standards for Personally Identifiable Information (PII) and comply with the California Consumer Protection Act (CCPA).
#
# 5. **HIPAA Compliance**:
#    - Adhere to HIPAA standards for medical record data storage.
#
# 6. **Integration and Reporting**:
#    - Address integration challenges with modern third-party systems and enhance historical data reporting.
#
# 7. **Elimination of Workarounds**:
#    - Reduce or eliminate workarounds such as duplicate data entry and reliance on extensive Excel spreadsheets.
#
# ### Additional Scopes:
#
# 1. **Contract Duration**:
#    - The contract begins upon execution and lasts until deliverables are completed or a specified termination date.
#
# 2. **Presentations and Demonstrations**:
#    - Selected vendors will demonstrate how their product meets Project Alpha's needs.
#
# 3. **Resources Provided by AGENTS**:
#    - Hardware for testing and third-party software systems for integration.
#
# 4. **Resources Provided by the Vendor**:
#    - End-to-End Testing Environment, Training Environment, Training Program, and software documentation.
#
# 5. **Training Program Development**:
#    - Create training materials for a “Train the Trainer” methodology.
#
# 6. **Software Documentation**:
#    - Develop manuals and user guides detailing system features.
#
# 7. **Software Licensing**:
#    - Acquire necessary software licenses for testing and training environments.
#
# 8. **Technical Deliverables**:
#    - Ensure all technical deliverables conform to a standard format, including delivery methods and testing methodologies.
#
# 9. **System Requirements**:
#    - Implement management systems for Purchase Orders, Budgets, Grants, Contracts, and Inventory.
#
# 10. **Client Intake Features**:
#     - Incorporate functionalities like geo-location, custom income calculations, and media uploads.
#
# 11. **Reporting and Document Generation**:
#     - Develop a report dashboard and implement mail merge capabilities.
#
# 12. **Timesheet Management**:
#     - Create functionalities for salary, hourly employees, and volunteers, ensuring timesheets tie back to grant-funded activities.
#
# 13. **Labor Cost Management**:
#     - Track total labor costs and provide breakdowns by type.
#
# 14. **Custom User Form Creation**:
#     - Develop customizable data entry forms and manage surveys.
#
# 15. **Data Integration with Third-Party Systems**:
#     - Implement APIs for data export and import tailored to program needs.
#
# 16. **Data Security**:
#     - Ensure HIPAA compliance and protect PII.
#
# 17. **Accounting Management**:
#     - Utilize Blackbaud Financial Edge for accounting needs and integrate with third-party systems.
#
# 18. **Volunteer and Vendor Management**:
#     - Manage volunteer resources and vendor relationships.
#
# 19. **Event and Donor Management**:
#     - Plan community engagement events and maintain donor relations.
#
# 20. **Project Management**:
#     - Conduct regular status check-ins, manage change requests, and provide progress reports.
#
# 21. **Quality Assurance Testing**:
#     - Conduct internal QA testing and facilitate User Acceptance Testing (UAT).
#
# 22. **Production Deployment and Support**:
#     - Provide production deployment services and post-production support.

# %% [markdown]
# ### **General Context for Company Profile**
# -----

# %%
print(rag_chain.extract_company_general_context())
# Out:
# **Company Background Summary:**
#
# AddAxis.AI is a leading artificial intelligence company with over seven years of experience in delivering AI solutions across Australia and the JAPAC region. The company specializes in transforming complex data into actionable insights, enabling organizations to leverage AI for agility, security, and innovation. With a team of over 20 AI researchers, data scientists, and engineers, AddAxis.AI has a strong track record of completing projects on time, within scope, and on budget.
#
# The company excels in various AI/ML platforms, including AWS, GCP, Azure, and OpenAI, with particular expertise in Google’s suite of AI tools. AddAxis.AI focuses on natural language processing, computer vision, reinforcement learning, and AI ethics, providing tailored solutions that integrate seamlessly with clients' existing infrastructures. Recognized as one of the top ten machine learning companies in the Asia-Pacific region, AddAxis.AI is dedicated to demystifying AI technology and aligning it with real-world business outcomes, helping clients unlock new opportunities for innovation and growth.
#
# **Project Experience Summary:**
#
# 1. **Inventory Optimisation at Amazon.com**
#    - **Objective:** Locate lost inventory.
#    - **Outcome:** Innovated processes that recovered millions in lost inventory.
#
# 2. **Integration of Golang with ChatGPT**
#    - **Technologies Used:** Golang, ChatGPT.
#    - **Outcome:** Enhanced capabilities through successful integration.
#
# 3. **WHMCS Integration**
#    - **Objective:** Streamline operations.
#    - **Outcome:** Improved service delivery via integration.
#
# 4. **WordPress Plugin Development**
#    - **Objective:** Develop plugins for enhanced functionality.
#    - **Outcome:** Added features for WordPress users.
#
# 5. **Architectural Design for IoT Company in Australia**
#    - **Objective:** Lead design efforts for IoT solutions.
#    - **Outcome:** Established a robust architectural framework for IoT applications.
#
# 6. **Solutions Development for the Bureau of Meteorology using AI**
#    - **Objective:** Leverage AI for meteorological applications.
#    - **Outcome:** Developed innovative solutions to enhance weather data analysis.
#
# This summary highlights the key projects, their objectives, technologies used, and outcomes, showcasing the company's expertise and achievements.
#
# **Product & Services Summary:**
#
# 1. **AI Solutions Design**: Comprehensive design of AI solutions that integrate seamlessly within existing ecosystems.
#
# 2. **Cloud AI Expertise**: Proficient in major cloud platforms including AWS (SageMaker, Bedrock), GCP (Vertex AI), and Microsoft AI.
#
# 3. **Data Warehousing**: Expertise in Snowflake, BigQuery, and Redshift for optimized data storage and retrieval.
#
# 4. **Reporting Tools**: Skilled in Microsoft Power BI, Google Looker, and AWS Quicksight for data reporting.
#
# 5. **Security and Reliability**: Focus on DevSecOps practices, utilizing infrastructure as code and GitOps for secure deployments.
#
# 6. **API Design and Management**: Development and management of APIs for AI integrations.
#
# 7. **MLOps (Machine Learning Operations)**: Streamlining deployment, management, and monitoring of machine learning models in production, enhancing collaboration among data scientists, engineers, and operations teams.
#
# 8. **Microservices Architecture**: Offers scalability, flexibility, and maintainability for applications, with features like improved fault isolation, faster deployment, and better alignment with business domains.
#
# 9. **Serverless Computing**: Enables building and deploying applications without managing server infrastructure, focusing on code deployment, automatic scaling, and reduced operational overhead.
#
# 10. **CAIO as a Service**: Provides strategic AI leadership and tailored AI solutions, offering access to a fractional Chief Artificial Intelligence Officer for organizations lacking in-house AI leadership.
#
# 11. **Rapid AI Proof of Concept (RAPoC)**: A service to test the validity of AI ideation, including advisory and consulting services in AI.
#
# 12. **Audio Analysis**: Bespoke audio analysis solutions using signal processing and machine learning to extract and interpret audio data.
#
# 13. **Computer Vision**: Solutions utilizing advanced computer vision technologies to enhance business efficiency and security measures.
#
# 14. **Generative AI Application**: Bespoke solutions using Generative AI and Large Language Models (LLMs) to enhance operational efficiency.
#
# 15. **Network Analysis**: Specializes in extracting insights from complex data relationships using advanced algorithms and machine learning techniques.
#
# 16. **Natural Language Processing (NLP)**: Comprehensive solutions to interpret, generate, and analyze text at scale, enabling organizations to gain insights and enhance customer engagement.
#
# **Unique Selling Propositions**:
# - Commitment to ethical AI development, ensuring solutions are socially responsible.
# - Focus on enhancing operational efficiency and driving data-driven strategies.
# - Deep AI experience with a culture of agility and waste minimization.
#
# **Customer Base**: Organizations across various industries, including public and private sectors, startups, and government entities.
#
# **Pricing Models**: Not explicitly mentioned in the provided text.
#
# ### Team Members Summary
#
# 1. **Dr. Alex Antic - Advisor**
#    - **Experience:** 18+ years in Advanced Analytics, Machine Learning, AI, Mathematics, and Statistics.
#    - **Domains:** Government, Asset Management, Insurance, Academia, Banking, Consulting.
#    - **Achievements:** Top 5 Analytics Leaders in Australia (IAPA, 2021).
#    - **Qualifications:** Ph.D. in Applied Mathematics, First Class Honours in Pure Mathematics, double degree in Mathematics and Computer Science.
#    - **Roles:** Senior advisory positions across industry, government, start-ups, and academia.
#
# 2. **Mark Ridley - Advisor**
#    - **Experience:** Independent director and executive adviser with expertise in governance, risk, and control.
#    - **Current Roles:** Independent chair of audit & risk committees for the Department of Foreign Affairs and Trade and the Australian Signals Directorate.
#    - **Responsibilities:** Governance, risk management, and financial oversight.
#
# 3. **Timothy Scholes - Founder**
#    - **Role:** Founder leading technology initiatives and strategy.
#    - **Experience:** Background at Macquarie Bank, Commbank, Qantas Insurance, AWS, and A Cloud Guru; founder of multiple tech start-ups.
#    - **Skills:** Cloud computing, algorithms, data, machine learning, AI, and data strategies.
#    - **Qualifications:** M.Sc in Applied Mathematics (cum laude), Executive MBA, B.Sc in pure mathematics and chemistry; Ph.D. candidate in Quantum Computing.
#
# 4. **Brett Dutton - Technical Product Lead**
#    - **Experience:** Over 30 years in computer technology across Medical, Supply Chain, Payment Cards, and Telecommunications.
#    - **Responsibilities:** Managing data centres, delivering training, and developing software products.
#    - **Achievements:** Innovated inventory optimisation at Amazon.com, integrated Golang with ChatGPT, led IoT architectural design, and developed AI solutions for the Bureau of Meteorology.
#
# 5. **Genevieve Kelly - Informal Advisor**
#    - **Experience:** 14+ years in Google Product and GTM roles, focusing on product-led growth and partnerships.
#    - **Responsibilities:** Strategy, operations, and delivery in product management.
#    - **Qualifications:** EMBA from Sydney University, BA from UTS; currently pursuing a PhD on sustainability transitions and climate software startups.
#
# 6. **Luokun Gong - Technical Lead**
#    - **Experience:** Strong background in Audio Processing, Face Recognition, and Large Language Model projects.
#    - **Skills:** Software Development Management and problem-solving in technology.
#    - **Responsibilities:** Navigating complex projects and delivering results in software development.

# %% [markdown]
# ### **Query Answering**
# -----

# %% [markdown]
# #### **Query 1**

# %%
print(rag_chain.query_answering("How to perform cybersecurity?"))
# Out:
# To effectively perform cybersecurity, especially in the context of developing a new enterprise data system as outlined in the AGENTS RFP, the following key strategies should be implemented:
#
# 1. **Integrate Security into Development (DevSecOps)**:
#    - Adopt a DevSecOps approach to embed security practices throughout the software development lifecycle. This ensures that security is a shared responsibility among all team members, allowing for early detection of vulnerabilities and reducing risks associated with software deployment.
#
# 2. **Compliance with Security Standards**:
#    - Ensure that the new system complies with security standards for Personally Identifiable Information (PII), including the California Consumer Protection Act (CCPA) and HIPAA for medical data. This involves implementing robust data encryption, access controls, and regular audits to safeguard sensitive information.
#
# 3. **Secure API Development**:
#    - As the new system will require data sharing with partners, it is crucial to design secure APIs that facilitate safe data exchange. This includes implementing authentication mechanisms, rate limiting, and monitoring for unusual activity to prevent unauthorized access.
#
# 4. **Data Protection Measures**:
#    - Utilize advanced data protection techniques, such as encryption at rest and in transit, to secure sensitive data. Regularly update and patch systems to protect against known vulnerabilities, leveraging the cloud provider's capabilities for automatic patching and secure execution environments.
#
# 5. **User Training and Awareness**:
#    - Develop a comprehensive training program for users to raise awareness about cybersecurity best practices. This includes educating staff on recognizing phishing attempts, secure password management, and the importance of reporting suspicious activities.
#
# 6. **Incident Response Planning**:
#    - Establish a clear incident response plan that outlines procedures for identifying, responding to, and recovering from security incidents. This plan should include roles and responsibilities, communication strategies, and post-incident analysis to improve future security measures.
#
# 7. **Regular Security Audits and Testing**:
#    - Conduct regular security audits and penetration testing to identify and address vulnerabilities proactively. This aligns with the RFP's requirement for quality assurance testing and ensures that the system remains secure against evolving threats.
#
# 8. **Collaboration with Security Experts**:
#    - Leverage the expertise of team members like Dr. Alex Antic and Brett Dutton, who have extensive backgrounds in advanced analytics and technical product management, to guide the implementation of security measures tailored to the specific needs of AGENTS.
#
# By implementing these strategies, AddAxis.AI can ensure that the new enterprise data system not only meets the functional requirements outlined in the RFP but also adheres to the highest standards of cybersecurity, ultimately enhancing the safety and integrity of AGENTS' operations.

# %% [markdown]
# #### **Query 2**

# %%
print(rag_chain.query_answering("What is the deadline for the bid?"))
# Out:
# The deadline for submitting bids in response to the Request for Proposal (RFP) issued by AGENTS has not been explicitly mentioned in the provided context. It is advisable to refer directly to the RFP document or contact AGENTS for specific details regarding the submission deadline.
#
# At AddAxis.AI, we are committed to delivering timely and effective solutions, and we would be eager to discuss how our expertise in AI and data systems can meet AGENTS' needs for a new enterprise data system. Our experience in system integration and compliance with security standards, particularly in handling Personally Identifiable Information (PII) and HIPAA regulations, positions us well to support AGENTS in this critical project.

# %% [markdown]
# #### **Query 3**

# %%
print(rag_chain.query_answering("How can the system enhance communication processes within the organization and with external partners?"))
# Out:
# The new enterprise data system proposed for AGENTS can significantly enhance communication processes both within the organization and with external partners through several key features and capabilities, leveraging AddAxis.AI's expertise in AI solutions and system integration.
#
# ### Internal Communication Enhancements:
#
# 1. **System-Wide User Access**: The new system will provide all staff with easy access to necessary information, enabling quick lookup and routing of inquiries. This feature fosters better collaboration among over 150 users, ensuring that everyone can access the data they need to perform their roles effectively.
#
# 2. **Access to Staff Calendars**: By integrating staff calendars, the system will facilitate better scheduling and coordination of meetings, improving internal communication and collaboration among team members.
#
# 3. **Referral Management**: The ability to manage referrals to both internal and external resources will streamline communication processes, ensuring that clients receive appropriate assistance and that staff can track referrals effectively.
#
# 4. **Documentation of Communication**: Features such as recording the "Reason for Call" and time spent per call will enhance accountability and provide insights into communication efficiency, allowing for continuous improvement in service delivery.
#
# 5. **Regular Status Meetings and Reporting**: The implementation of structured project management practices, including weekly and monthly reports, will ensure that all stakeholders are informed of progress, roadblocks, and accomplishments. This transparency fosters a culture of open communication and collaboration.
#
# ### External Communication Enhancements:
#
# 1. **API Integration for Data Sharing**: The system will enable seamless data sharing with external partners through APIs, facilitating collaboration and ensuring that all parties have access to the necessary information for effective decision-making.
#
# 2. **Vendor and Volunteer Management**: By streamlining vendor intake and enhancing volunteer coordination, the system will improve communication with external partners, ensuring that relationships are managed effectively and that resources are utilized efficiently.
#
# 3. **Enhanced Client Interaction**: Features such as geo-location and custom income calculations in client intake will improve the user experience for clients, allowing for more personalized interactions and better service delivery.
#
# 4. **Project Management Collaboration**: The collaboration between AGENTS and external vendors through assigned project managers will ensure that communication is maintained throughout the project lifecycle, with regular status check-ins to keep all stakeholders informed.
#
# 5. **Support Availability**: Providing support during specified working hours will ensure that AGENTS can communicate issues and receive assistance promptly, enhancing overall communication efficiency with external partners.
#
# ### Unique Selling Propositions of AddAxis.AI:
#
# - **AI-Driven Insights**: Leveraging AddAxis.AI's expertise in AI and data analytics, the system can provide actionable insights that enhance decision-making and improve communication strategies.
#
# - **Ethical AI Development**: AddAxis.AI's commitment to ethical AI ensures that the solutions developed are socially responsible, fostering trust and transparency in communications with clients and partners.
#
# - **Tailored Solutions**: The ability to customize the system to meet AGENTS' specific needs will ensure that communication processes are aligned with organizational goals and community needs.
#
# In summary, the new enterprise data system will enhance communication processes within AGENTS and with external partners by providing robust features for information access, referral management, and data sharing, all while leveraging AddAxis.AI's unique capabilities in AI and system integration. This will ultimately lead to improved operational efficiency, better service delivery, and stronger partnerships.

# %% [markdown]
# #### **Query 4**

# %%
print(rag_chain.query_answering("What are the expectations for the Management Information Systems team in terms of supporting the new system?"))
# Out:
# The expectations for the Management Information Systems (MIS) team in supporting the new system for AGENTS are multifaceted and critical to the successful implementation and ongoing operation of the enterprise data system. Key expectations include:
#
# 1. **Day-to-Day Management**: The MIS team will be responsible for the daily operation and management of the new system, ensuring that it runs smoothly and efficiently for over 150 users.
#
# 2. **User Support and Training**: They will need to facilitate user training, particularly through a "Train the Trainer" methodology, to ensure that staff can effectively utilize the new system. This includes developing training materials and providing ongoing support to users.
#
# 3. **System Maintenance and Troubleshooting**: The team will be expected to handle system maintenance, troubleshoot issues, and provide timely resolutions to any technical problems that arise, ensuring minimal disruption to services.
#
# 4. **Data Security Compliance**: Given the importance of compliance with security standards for Personally Identifiable Information (PII), including CCPA and HIPAA, the MIS team will need to implement and monitor security protocols to protect sensitive data.
#
# 5. **Integration Management**: The team will oversee the integration of the new system with existing third-party systems, such as Blackbaud Financial Edge, ensuring seamless data flow and functionality.
#
# 6. **Reporting and Data Management**: They will be responsible for managing data reporting capabilities, including the development of customizable reports and dashboards that meet the needs of various stakeholders.
#
# 7. **Documentation and User Guides**: The MIS team will play a key role in creating comprehensive manuals and user guides that detail system features, ensuring that all users have access to the necessary resources for effective system use.
#
# 8. **Quality Assurance and User Acceptance Testing (UAT)**: They will be involved in quality assurance testing and facilitating UAT to ensure that the system meets the specified requirements and functions as intended.
#
# 9. **Project Management Support**: The team will assist in project management activities, including regular status updates, managing change requests, and ensuring that the project stays on track.
#
# 10. **Vendor Coordination**: They will coordinate with the selected vendor(s) for ongoing support and maintenance, ensuring that any issues are addressed promptly and that the system continues to evolve with AGENTS' needs.
#
# By leveraging AddAxis.AI's expertise in AI solutions, cloud integration, and data management, the MIS team can enhance their capabilities in supporting the new system, ensuring it aligns with AGENTS' goals of improving operational efficiency and service delivery. The team's familiarity with advanced technologies and commitment to ethical AI development will further support AGENTS in achieving a robust and compliant data management system.

# %% [markdown]
# ### **Question Extraction**
# ------

# %%
for question in rag_chain.retrieve_question_with_question_mark_using_regex():
    print(question)

# %%
for question in rag_chain.retrieve_question_without_question_mark():
    print(question)
# Out:
# How will the new system accommodate the needs of a 150+ user base while ensuring efficient data management and access?
# What estimating methodology was used to determine the effort associated with the project?
# How can the system facilitate data integration with third-party systems such as Avista and the State of Washington Department of Commerce?
# Can you provide customer service references to support the proposal?
# How does the proposed system's purchase order module differ from AGENTS' requirements, and what specific enhancements can be made to align it with those needs?
# What specific methodologies will be used for the Software Development Life Cycle in the project?
# What are the expectations for the Management Information Systems team in terms of supporting the new system?
# How will the system support the upload and management of media associated with various entities (Client, Vendor, Staff, Project, etc.)?
# How can the system enhance communication processes within the organization and with external partners?
# Can you provide a minimum of three references from the past two years for similar products or services?
# What criteria will be used to assess the vendors' background information and their ability to meet the project objectives?
# Can you provide an overview of your company, including date of incorporation, operating locations, number of employees, areas of specialty, and successful projects with Non-Profit / Community Action Program customers?
# What is the proposed timeline for project completion?
# What mechanisms will be available for data sharing with partners, and how will API interactions be implemented in the new system?
# How will the system handle job costing and the allocation of funding sources to different cost centers?
# What management information systems will be utilized?
# What support mechanisms will be in place during the warranty period, and how will defects be reported and addressed?
# Are you a woman or minority owned business?
# What contributions are expected from each unique skill set involved in the project?
# What are the identified risks associated with the project, and what is the proposed response to each risk?
# How will time spent per call be recorded and managed within the system?
# Can you provide sample data from the estimating process to illustrate the methodology?
# How can we better track and report the impact of allocated hours on the outcomes of each activity?
# What is the purpose of this request for proposal?
# What strategies will be employed for effective referral management to both internal and external resources?
# What is the estimated cost proposal for the project?
# What features will be included for effective data integration with third-party systems, such as the current HMIS and loan systems?
# What are the specific standards and conventions that the software code must comply with, and how will these be enforced?
# What are the criteria for vendor management and vendor license management within the proposed system?
# What potential risks have been identified, and what mitigation strategies are proposed?
# How will engagement governance be structured?
# What housing requirements must be considered?
# How can existing modules be utilized and customized to meet the requirements without additional software purchases or major development efforts?
# What assumptions are being made in the vendor's proposal?
# How will the proposal address the management and tracking of volunteer resources across various programs?
# Which testing tools and instruments do you use?
# How will the timesheet allocation process be managed to ensure accurate tracking of hours worked and funding from multiple grants?
# How will data integration with third-party systems be facilitated, and what APIs will be supported for data export and import?
# What is the specification of the project organizations with which you have experience (e.g., onshore, offshore, onshore PM, offshore dedicated development team, etc.)?
# How do you screen and hire staff, and what level of skill and certifications must they have?
# What solutions can be proposed to ensure seamless integration between the new Community Action system and the Blackbaud Financial Edge package?
# Do you require background checks on all employees, and how often are these checks updated?
# What specific project methodology will be employed to initiate, maintain, and close out the project?
# Can you describe your experience with Visual Fox Pro, including any past data conversion experience with this technology, and do any team members hold certifications in it?
# What specific information will be considered confidential, and what are the terms of the Non-Disclosure Agreement?
# What specific reporting capabilities will be available for generating complex reports beyond the customizable reporting solution?
# What is the target deployment platform operating system for the proposed system?
# How will time spent per call be recorded and reported?
# How will project management responsibilities be divided between AGENTS and the vendor, and what communication protocols will be established?
# What programming language will be used to develop the proposed system?
# What are the specific accounting requirements for the project?
# What strategies can be implemented to increase the logged hours for each fund to better reflect actual work and contributions?
# Do you use internal staff for project management or third-party system integration teams?
# What assumptions have been made regarding project execution and AGENTS' activities?
# How can we improve the allocation of hours across different funding sources to ensure equitable distribution of resources?
# What is the process for capturing referrals to external resources and recording the reason for calls?
# What features and functionalities will the new system provide to enhance user experience and support the growth of AGENTS programs?
# What specific assumptions have been made regarding the execution of the project and the activities of AGENTS?
# What third-party software systems currently in use will require integration, and what are the licensing requirements?
# What is the proposed timeline for the implementation of the new system, and what are the key milestones?
# What processes will be established for event management and donor engagement?
# What customizable features will be available for calculating benefits and managing job costing across different cost centers?
# What measures will be taken to ensure HIPAA compliance for data exports to partners?
# What relevant experience does the vendor have in similar projects?
# What is your experience with Visual Fox Pro, and do you have any past data conversion experience with this technology?
# What energy-related specifications need to be addressed?
# What is the target deployment platform operating system?
# How will the Communications team enhance community outreach and donor management?
# What systems will be in place for inventory management and task management?
# What standard format will be agreed upon for the delivery of technical deliverables, and what specific elements will it include?
# How will the new system facilitate API interactions or other methods for sharing data with partners?
# What communication protocols are expected to be established?
# What criteria will AGENTS use to determine which vendor proposals are deemed reasonably susceptible for award consideration?
# What is the timeline for implementation and cutover, and how will it be evaluated during the proposal process?
# How can we improve the allocation of general hours to ensure more effective utilization of resources across different funds?
# What Software Development Life Cycle do you use for customizations, defects, and system upgrades related to AGENTS customizations?
# Have you worked on projects for Non-Profit Community Action Programs with similar functionality? If so, please describe the project, scope, team size, duration, and project management model.
# What internal Quality Assurance testing processes does the Vendor implement before deploying new software to AGENTS?
# How will staffing be structured for the project?
# What strategies will be implemented for effective data integration with third-party systems, such as the current HMIS and loan systems?
# What specific enhancements to the overall business processes are expected from the new software system?
# What are the expectations regarding the support and maintenance of the software after implementation?
# Can you provide a minimum of three references from the past two years for similar products or services, including contact details and physical addresses?
# What criteria will be used to evaluate the proposals submitted by vendors?
# What industry standards and conventions will be followed for software code quality and documentation?
# What strategies can be implemented to better track and report activity hours versus vacation and meeting hours?
# What format will the monthly progress report take, and how will it ensure clarity in communicating project status regarding Scope, Schedule, and Budget?
# What custom features need to be included in the software manuals and user guides?
# What level of time and support will AGENTS provide to the vendor during the project?
# How do you ordinarily scope, estimate, assign resources, and measure progress in your projects?
# What specific needs of Project Alpha should vendors address in their presentations and demonstrations?
# What protocols will be followed for client intake and management across various programs, including loan and home repair assistance?
# What was the service provided, and what was your role in the creation/deployment of the solution?
# What features should be included to maintain multiple years of data for the Energy Program while allowing for client resets without losing historical data?
# How will the integration with third-party systems, such as Avista and Financial Edge, be managed to ensure seamless data flow?
# What strategies will be employed to ensure accurate allocation of labor costs across projects?
# What additional software purchases are available to integrate with the proposed system, and how do they address the unmet requirements?
# How does the proposed system's purchase order module differ from AGENTS' needs, and what specific enhancements can be made to align it with those needs?
# How can the timesheet module be enhanced to improve user experience and accuracy in recording time against activities?
# What training and support will be provided to users during and after the transition to the new system?
# What strategies will the Vendor implement to identify, document, and escalate risks within one day as required?
# What is the expected duration of the project and the specific termination date for the contract?
# What processes will be established for event management and donor management?
# Do you employ any overseas resources?
# What specific features and functionalities are required for the system-wide user access for information lookup and routing?
# What mechanisms will be implemented to ensure secure data storage and exchange in compliance with CCPA and HIPAA standards?
# What database technology does the proposed system require?
# How will the system ensure compliance with HIPAA standards for programs that store sensitive data?
# What measures will be implemented to protect Personally Identifiable Information (PII) within the system?
# How will the proposed software development solutions enhance the core areas of AGENTS’s service, including Housing Services, Community Action, and Financial Stability?
# How will the Vendor demonstrate their experience and capabilities with the technologies used in the AGENTS ecosystem?
# What services will be provided under the Homeless Assistance Program, and how will client intake be managed?
# What project management methodologies will be employed?
# What processes will be in place for Change Request Management, and how will the Vendor handle requests that fall outside the initial project scope?
# What criteria will AGENTS use to determine which vendor proposals are deemed reasonably susceptible for award after discussions?
# What is the expected contract term for the project?
# How will the integration with third-party systems, such as Financial Edge, be achieved and what data will be shared?
# How will the new system ensure compliance with security standards for Personally Identifiable Information (PII) and HIPAA regulations?
# What database technology is required for the proposed system?
# Have you worked on projects for Non-Profit Community Action Programs with similar functionality? Please describe the project, scope, team size, duration, and project management model.
# How will the system accommodate independent management of programs while ensuring flexibility in features like Purchase Order Management and Budget Management?
# What functionalities are needed for efficient volunteer management and vendor intake and management within the new system?
# What strategies will be employed to support the Homeless Assistance Program, particularly in rapid rehousing and rental assistance?
# What are the expected working hours for support, and how will these be determined during contract negotiations?
# What methodologies do you use for testing?
# What is the proposed project timeline, including major milestones and deliverable dates?
# How will the system support the upload and management of media associated with various entities?
# What is your server patching policy, and if cloud-based, how much planned downtime is there per year?
# What risks have been identified in the proposal, and what mitigations are suggested?
# How will the new system support historical data reporting and analysis?
# What strategies will be implemented for effective volunteer management and engagement?
# How will the Vendor ensure timely communication and escalation of risks and issues to the AGENTS contact?
# What is the breakdown of the project cost proposal by category, including initial software costs, customizations, installation, and support?
# Are you a woman or minority-owned business, and how does this status impact your operations?
# What are the definitions of key terms used in the proposal?
# What is the proposed defect report process flow, and how will defects be prioritized and resolved?
# What functionalities are needed for effective volunteer management and vendor intake and management within the new system?
# How will timesheet management be integrated with grant funding and project activities?
# How can we improve the allocation of hours to ensure more effective use of employee time across different funding sources?
# What is the role of the internal resource team in the project?
# What is the Software Development Life Cycle utilized for customizations, and how does it outline the testing and deployment procedures?
# How will timesheets be integrated with activities funded by multiple grants, and what reporting features will be available for labor costs in projects?
# What capabilities will be included in the report dashboard, and how customizable will the mail merge and fillable forms be?
# What is the breakdown of the project cost proposal by various categories, including initial software cost, customization, installation, and post-project support?
# What are the total project hours allocated for each task/resource category?
# What is your experience level and PMP certification status in project management?
# Can the Vendor provide a detailed outline of the Software Development Life Cycle they will utilize for customizations, including testing and deployment procedures?
# What format will be used for the weekly and monthly reports on progress and roadblocks, and how will they be color-coded for status?
# What standard documentation do you produce during the development process?
# What are the technical and data conversion requirements?
# What workflow management features will be implemented to streamline operations within the Internal Resource Team?
# How will discussions and best and final offers be conducted?
# What standards and conventions must be adhered to during the project?
# How can we adjust the percentage allocations for different activities to reflect actual employee workload and project needs?
# How do you evaluate staff experience and performance, and what was your staff turnover rate for the preceding three years?
# What methods will be used to implement geo-location features and custom calculations for income and poverty?
# What methods will be used to implement custom income and percentage poverty calculations, and how will these be validated?
# How will the proposed system ensure compliance with HIPAA regulations while managing sensitive client information across various programs?
# What measures will be taken to protect Personally Identifiable Information (PII) stored within the system?
# How are activities configured and managed within the timesheet system to ensure accurate allocation to funding sources?
# How can we assess the impact of last month's allocation percentages on the overall performance and outcomes of the funded activities?
# How will the Vendor ensure timely and accurate reporting of project progress and roadblocks on a weekly and monthly basis?
# What specific updates are required for the purchase order module to fully meet the business requirements of AGENTS?
# Can you detail the overall systems requirements for the project?
# How will the project management responsibilities be divided between AGENTS and the vendor, and what are the expectations for coordination?
# How will the ownership of deliverables be managed between AGENTS and the vendor?
# What are the required skill sets, numbers, and locations of the individuals proposed for staffing the project?
# What experience do you have with different project organizations, such as onshore, offshore, onshore PM, or offshore dedicated development teams?
# Do you utilize internal staff for project management, or do you engage third-party system integration teams?
# What specific methodologies will the Project Management Team at AGENTS employ to ensure effective management of the project?
# What strategies will be employed to ensure the new system can integrate with modern third-party systems and reduce the need for duplicate data entry?
# Can the vendor provide references from previous projects?
# What additional fields are needed in the purchase order module, and how can they be integrated using the existing Custom Field process?
# Are any team members certified in Visual Fox Pro?
# What is the proposed process flow for defect reporting and resolution?
# What are your experience levels and PMP Certifications in project management?
# What processes will be implemented for conducting User Acceptance Testing (UAT)?
# How will educational course management be handled, including creation and registration for local and web-based courses?
# What customization options are available for the proposed system, and what would be the estimated effort and cost for major software development?
# How will the proposal address the management of volunteer resources and their integration into the various housing programs?
# What resources will be provided by AGENTS, and what resources are expected from the vendor?
# What are the potential challenges and benefits of customizing existing modules to meet the requirements?
# How will geo-location and GPS nets be utilized to define specific metropolitan areas and layer districts?
# What capabilities will be included for report generation, mail merge, and customizable forms?
# What specific features and functionalities will be included in the system for staff calendar access and referral management?
# What is the approach for managing client intake and documentation for various assistance programs, including home repair and mortgage assistance?
# What strategies can be implemented to optimize the efficiency of energy and homeless activity programs based on the current hour allocations?
# What defect tracking system is used during the QA lifecycle, and how will AGENTS team access it?
# How will the "Ride to Care" component be integrated into the project?
# How will the relationship between AGENTS and your company be structured throughout the project?
# What processes will be in place for capturing and managing the "Reason for Call" and time spent per call in the Internal Resource Team's operations?
# How can the new system support the management and reconfiguration of the Energy Program in accordance with changing state and federal regulations and funding sources?
# What is your testing methodology and QA approach?
# How successful was this experience, and what lessons learned were implemented?
# How will the vendor's project management capabilities be evaluated?
# How do you scope, estimate, assign resources, and measure progress in projects?
# What testing procedures will be implemented?
# What features will be included in the customizable data entry fields to ensure they can perform necessary calculations and reporting?
# What are the evaluation criteria for assessing vendor proposals?
# Can you provide background information on the services required for Project Alpha?
# What is the vendor's proposed project approach?
# How does the AGENTS team participate in User Acceptance Testing, and what criteria do they use for final approval?
# How will the proposed software development solutions enhance the core areas of AGENTS's services, such as Housing Services, Community Action, and Financial Stability?
# What training offerings and ease of implementation can be provided with the proposed solution?
# How does the proposed system plan to expand to meet future needs?
# Is the proposing business a woman or minority-owned business?
# What is the vendor's experience and background in providing System Integrator services for similar organizations or projects?
# What is your Software Release cycle for new features, and how often is the overall system updated for security patches?
# What support and warranty services will be provided post-implementation, and what are the specific terms of the warranty?
# What is your experience level and PMP certification status in project management, and how do you typically scope, estimate, assign resources, and measure progress?
# How will the overall initial cost and yearly costs be structured in the proposal?
# What are the requirements for presentations and demonstrations during the proposal process?
# What is the extent of functionality (50%-80% or 80%+) that the proposed system currently offers, and what are the specific areas that require customization?
# What are the expectations for the Training Program and documentation to support the "Train the Trainer" methodology?
# What warranty and support services will be provided post-implementation?
# What inventory management capabilities will be included to support the Housing Program's needs?
# What measures will be taken to ensure effective inventory management and vendor bid management within the housing program?
# What technical experience does the vendor possess that is relevant to this project?
# What criteria will AGENTS use to evaluate the quality of work performed on this project for potential follow-on contracts?
# Do you use internal staff for project management or third-party system integration teams?
# What are the specific payment terms outlined in the proposal?
# What will be the agenda and frequency of the Project Management Status Check-in meetings?
# What specific features and functionalities should the End to End Testing Environment support?
# What capabilities should be included for effective client intake and management, especially for emergency situations?
# Which software development lifecycle model would you choose for this project and why?
# Is the proposing company a woman or minority-owned business?
# Which software development lifecycle model would you choose for this project, and what is your rationale for that choice?
# What is the expected time to implement the proposed solution?
# What level of customization or software development effort is required to meet the outlined requirements, and what resources are available for this effort?
# What customizable calculations and lifetime limits can be implemented for benefits in the Housing Program?
# How will the system facilitate efficient referral management to both internal and external resources, such as 211?
# What is the timeline for implementation and cutover for Project Alpha?
# How does the existing functionality of the proposed system (50%-80% availability) impact its overall effectiveness for AGENTS?
# What specific time and resource requirements from AGENTS are necessary to support the project effort?
# What measures will be taken to ensure the non-disclosure of confidential information?
# What custom data calculation formulas are necessary for the Energy Program, and how can they be effectively implemented in the new system?
# What provisions are in place for addressing homelessness within the project?
# How will the Financial Stability program be structured to assist clients with home purchases and small business loans?
# How will documentation be provided to ensure clarity and usability for end-users?
# What processes are in place to monitor and adjust the allocation percentages for General Time when the recorded billable hours fall below the required threshold?
# What are the hourly rates for the various roles and skill levels assigned to the project?
# How will the proposed system ensure compliance with HIPAA regulations across all service areas?
# How will the proposal support the management of multiple configurable hourly rates for labor across different projects?
# What processes will be in place for capturing referrals to external resources and recording the reasons for calls?
# How will the system facilitate efficient vendor bid management and vendor license management?
# What production deployment and post-production emergency support does the Vendor provide after changes are deployed to the production environment?
# What types of customization are anticipated for the new software system, and how will these be defined?
# What specific requirements does the proposed system fail to meet, and what are the implications of these gaps?
# How does the AGENTS team participate in the User Acceptance Testing process, and what criteria do they use for final approval?
# How can the system ensure compliance with HIPAA regulations, particularly regarding data export to partners?
# What is your testing methodology and QA approach, including the testing tools and instruments you use, the methodologies you follow, and the standard documentation produced during the development process?
# What are the criteria for vendor management and how will vendor licenses be tracked and managed?
# How will financial stability be assessed in the context of the project?
# What are the specific milestone payment terms associated with the fixed price payment structure?
# What specific business rules, fields, formulas, forms, or user data entry screens need to be customized in the software to meet AGENTS's requirements?
# How will the integration with third-party systems, such as Financial Edge, be managed and what are the expected outcomes?
