# %%
from RAG_Chain import *
rag_chain = RAG_Chain()
# Out:
# /Users/stev/opt/anaconda3/lib/python3.9/site-packages/langchain_ollama/__init__.py:4: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   from langchain_ollama.embeddings import OllamaEmbeddings

# %% [markdown]
# ### **General Context for RFP**
# -----

# %%
print(rag_chain.extract_RFP_general_context())
# Out:
# **Background Summary:**
#
# The Australian Securities and Investments Commission (ASIC) is focused on stabilizing and enhancing its legacy Registry environments following the closure of the Modernising Business Register (MBR) Program in September 2023. ASIC is currently facing significant risks due to the reliance on aging systems and applications while new registry environments are being developed. To address these risks, ASIC is seeking a supplier to provide and manage skilled resources for the support of these legacy systems over a potential 3–5-year period.
#
# ASIC is particularly interested in suppliers who can:
# 1. Provide IT professionals with the necessary experience, skills, and knowledge for software development and infrastructure activities related to the ASIC Registry Platforms.
# 2. Offer resources to support the hardware infrastructure for these platforms.
#
# ...

# %% [markdown]
# ### **General Context for Company Profile**
# -----

# %%
print(rag_chain.extract_company_general_context())
# Out:
# **Company Background Summary:**
#
# AddAxis.AI is a leading artificial intelligence company with over seven years of experience in delivering AI solutions across Australia and the JAPAC region. The company specializes in transforming complex data into actionable insights, enabling organizations to leverage AI for agility, security, and innovation. With a team of over 20 AI researchers, data scientists, and engineers, AddAxis.AI has a strong track record of completing projects on time, within scope, and on budget.
#
# ...

# %% [markdown]
# ### **Query Answering**
# -----

# %% [markdown]
# #### **Query 1**

# %%
print(rag_chain.query_answering("How to perform cybersecurity?"))
# Out:
# To perform effective cybersecurity, organizations should adopt a comprehensive approach that integrates best practices, frameworks, and technologies. Here’s a structured methodology tailored to the context of AddAxis.AI and the requirements outlined in the ASIC RFP:
#
# ### 1. **Adopt a Security Framework**
#    - Implement frameworks such as the **Essential Eight Maturity Model** from the Australian Cyber Security Centre (ACSC) to establish a baseline for cybersecurity practices. This model emphasizes critical areas such as application whitelisting, patch management, and user access control.
#
# ### 2. **Embed Security in Development (DevSecOps)**
#    - Integrate security practices into the DevOps lifecycle, ensuring that security is a shared responsibility. This includes:
#      - **Early Detection of Vulnerabilities**: Utilize automated security testing tools during the development phase to identify and mitigate vulnerabilities before deployment.
# ...

# %% [markdown]
# #### **Query 2**

# %%
print(rag_chain.query_answering("What is the deadline for the bid?"))
# Out:
# The deadline for the bid is **01 November 2024 at 2:30 PM**.
#
# This timeline is crucial for AddAxis.AI as we prepare to leverage our extensive experience in AI solutions and our proven track record in delivering high-quality software development and infrastructure support. Our team, comprising experts in various AI/ML platforms and software development, is well-equipped to meet ASIC's requirements for resource augmentation and legacy system support. We are committed to ensuring compliance with ASIC's standards and delivering innovative solutions that align with their objectives.

# %% [markdown]
# #### **Query 3**

# %%
print(rag_chain.query_answering("What are the criteria for the recruitment, training, and retention of software developers by the Supplier?"))
# Out:
# The criteria for the recruitment, training, and retention of software developers by the Supplier, particularly in the context of the ASIC Registry Platform Resource Augmentation, should encompass the following key elements:
#
# ### Recruitment Criteria:
# 1. **Technical Expertise**: Candidates must possess core skills in mainframe programming, WebSphere MQ, Informix Database Administration, Java, XML, C/C++, Oracle Fusion Middleware, and system administration for Oracle Linux and Solaris. Familiarity with IBM DataPower Gateway and IBM Mainframe z15 T02 is also essential.
#
# 2. **Experience**: A proven track record in software development and infrastructure support, particularly in legacy systems, is crucial. Experience in similar regulatory environments or government projects would be advantageous.
#
# 3. **Cultural Fit**: Candidates should align with ASIC's values and work collaboratively within the Technology Team, fostering a culture of transparency and communication.
#
# ...

# %% [markdown]
# #### **Query 4**

# %%
print(rag_chain.query_answering("What strategies will you implement for the transition and onboarding of software developers into the ASIC Registry Platform?"))
# Out:
# To ensure a smooth transition and onboarding of software developers into the ASIC Registry Platform, AddAxis.AI will implement the following strategies, leveraging our extensive experience in AI solutions and project management:
#
# 1. **Comprehensive Onboarding Program**: We will develop a structured onboarding program tailored to ASIC's specific needs. This program will include an introduction to ASIC's culture, processes, and the technical environment of the Registry Platform. Our onboarding will also cover compliance with ASIC standards and the Web Content Accessibility Guidelines (WCAG) 2.0.
#
# 2. **Skill Assessment and Training**: Prior to onboarding, we will conduct skill assessments to identify the strengths and gaps of each developer. Based on these assessments, we will provide targeted training sessions on core skills required for the ASIC Registry Platform, including mainframe programming, Java, XML, and database management with Informix and Oracle.
#
# ...

# %% [markdown]
# ### **Question Extraction**
# ------

# %%
for question in rag_chain.retrieve_question_with_question_mark_using_regex():
    print(question)

# %%
for question in rag_chain.retrieve_question_without_question_mark():
    print(question)
# Out:
# How will the supplier ensure adherence to the quality and timeliness standards set by ASIC?
# Can you provide more details about the technologies (software and hardware) that comprise the ASIC Registry Platform?
# How do you envision the integration of the suppliers’ pool of software developers with the ASIC Technology Team?
# What is the proposed plan for transitioning to an SLA-based outsourced model during the contract term?
# What are the current team sizes and competencies for the existing teams working on the ASIC Registry Platforms?
# What hardware support and maintenance solutions are expected to meet the objectives outlined in section 3.2?
# How will the supplier ensure compliance with ASIC's standards and policies during the recruitment and training of software developers?
# What measures will be taken to align with the Privacy Act 1988 and the Australian Government ACSC Information Security Manual (ISM)?
# ...
