# %%
from RAG_Chain import *
rag_chain = RAG_Chain()
# Out:
# /Users/stev/opt/anaconda3/lib/python3.9/site-packages/langchain_ollama/__init__.py:4: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   from langchain_ollama.embeddings import OllamaEmbeddings
# /Users/stev/opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# ### **General Context for RFP**
# -----

# %%
print(rag_chain.extract_RFP_general_context())
# Out:
# **Background Summary:**
#
# The Fair Work Commission has established a system for updating wage rates and tables in awards through the MAPD, ensuring version control and access to up-to-date templates. In 2018, a database and platform were created to manage unique wage rates and allowances, containing historical data for awards dating back to 2015. This platform supports wage increases based on decisions and generates Word documents populated with data from the database, which includes both table formats and numerical figures.
#
# However, there is a need for a new implementation to streamline processes, as the existing system is heavily reliant on coding and requires significant programming knowledge, prompting the search for more user-friendly solutions. Integration with various services, including the MAPD API, is essential to support payroll companies and employers relying on the data.
#
# The Fair Work Commission Modern Awards Database aims to centralize the management of Award Pay Rates, formulas, calculations, and related data, serving as a repository for Commission Staff to access previous Award Rates, import and export data, and generate documents using templating and markup languages. Significant discovery has indicated that the current platform does not meet organizational needs, leading to a proposed reimagined approach that leverages Microsoft’s product suites and technology advancements to enhance document management, templating, data validation, and publishing capabilities. The project will include core modular components such as a document management system, a formula library for pay rate calculations, and a user-friendly document templating solution.
#
# The objectives of the Request for Proposal (RFP) focus on creating a robust and user-friendly system for managing awards. Key points include:
#
# 1. **Streamline Award Updates**: Simplify the process for updating rates in awards to reduce programming complexity.
# 2. **User-Friendly Solutions**: Develop easy-to-use tools for generating award documents without extensive programming knowledge.
# 3. **Maintain Integration**: Ensure compatibility with existing services, especially the MAPD API for accessing awards and rates.
# 4. **Enhance Version Control**: Keep the template document for award updates current through effective version control.
# 5. **Leverage Historical Data**: Utilize historical award data and unique wage rates from the existing database since 2015 for informed updates.
# 6. **Improve Document Generation**: Create efficient methods for generating Word documents from the database, minimizing coding dependencies.
# 7. **Support Existing User Base**: Address the needs of payroll companies and employers using the API during and after implementation.
# 8. **Centralized Repository**: Establish a centralized location for storing Award Pay Rates, formulas, calculations, and award clause information.
# 9. **Data Retrieval and Management**: Enable easy retrieval and management of previous award rates and related data, including import/export capabilities.
# 10. **Document Management**: Develop a system to manage the lifecycle of documents, including metadata related to awards.
# 11. **Formula Library**: Create a library for storing and calculating pay rates for each award.
# 12. **User-Friendly Templating Solution**: Provide a solution for modifying award templates without coding skills.
# 13. **Data Validation**: Implement processes to verify rates and calculations.
# 14. **Utilization of Technology**: Leverage Microsoft products to enhance document management and data validation.
# 15. **Address Current Limitations**: Reimagine the platform based on discovery findings to better meet organizational needs.
# 16. **Timely Delivery and Compliance**: Ensure timely project delivery within budget, adhering to privacy and security standards.
# 17. **Ongoing Support and Training**: Provide continuous support, training, and documentation for effective system use.
# 18. **Audit History and Versioning**: Implement audit trails for changes and maintain versioning for historical integrity.
# 19. **Management of Allowances and Penalties**: Establish systems for managing wage allowances and penalties accurately.
# 20. **Rounding Functionality**: Include rounding capabilities for calculations while preserving historical data integrity.
#
# These objectives aim to enhance the management of awards, improve document generation, and ensure ongoing support and compliance.
#
# ### Summary of Scopes from the RFP Document:
#
# 1. **Award Updates Management**: Develop a system to manage updates to rates and tables in awards, ensuring updates are reflected in generated template documents.
#
# 2. **Database Utilization**: Use the existing database with unique wage rates and allowances from 2018, enabling wage increases and generating Word documents populated with rates.
#
# 3. **Streamlining Processes**: Propose implementations to streamline current activities and reduce reliance on coding for template creation.
#
# 4. **Integration Maintenance**: Maintain integration with services, specifically the MAPD API, ensuring continued access for registered organizations.
#
# 5. **User-Friendly Solutions**: Explore solutions to enhance user-friendliness in document generation and award updates management.
#
# 6. **Document Management System**: Develop a system for managing the lifecycle of documents, including metadata and properties.
#
# 7. **Formula Library**: Create a library for storing and calculating rates of pay for each Award.
#
# 8. **Document Templating Solution**: Implement a solution for modifying Modern Award templates without coding.
#
# 9. **Data Validation**: Provide capabilities for data validation to ensure accuracy in calculations and rates.
#
# 10. **Import and Export Functionality**: Enable import and export of data related to Awards and documents.
#
# 11. **Document Generation**: Facilitate document generation based on stored information using templating.
#
# 12. **User Interface for Staff**: Develop dashboards for data validation and reporting.
#
# 13. **Solution Architecture**: Define the architecture for the formula library and document templating solution.
#
# 14. **Validation**: Validate the capabilities and limitations of the proposed solution.
#
# 15. **Environment Establishment**: Establish required environments within the Fair Work Commission's tenancies.
#
# 16. **Microsoft Technologies Utilization**: Use Microsoft 365, Dynamics, and Power Platforms, focusing on reusable elements.
#
# 17. **Data Import**: Import existing data into the new system.
#
# 18. **Support Model Transition**: Provide a support model for continuity of services.
#
# 19. **Project Delivery**: Meet designated timeframes and milestones within a fixed cost budget.
#
# 20. **Support SLAs**: Provide support Service Level Agreements for each location.
#
# 21. **Compliance**: Ensure compliance with the Privacy Act 1988 and Australian Privacy Principles.
#
# 22. **Security Standards**: Deliver work consistent with the Australian Government Information Security Manual.
#
# 23. **Contractual Arrangements**: Engage the seller through the BuyICT Digital Marketplace Deed of Standing Offer.
#
# 24. **Work, Health and Safety**: Conduct work offsite due to COVID-19, with teleconference meetings.
#
# 25. **Vendor Responsibilities**: Project management using MS Teams, with adherence to security policies and collaboration with the Change Advisory Board.
#
# 26. **Documentation**: Develop and maintain documentation, including User Acceptance Testing scripts and knowledge articles.
#
# 27. **Reporting**: Provide weekly updates to the ICT Project team and present to the Executive Team.
#
# 28. **Invoicing**: Ensure payment occurs within seven days of invoice approval.
#
# 29. **Evaluation Criteria**: Assess ability to meet requirements (50% weight), success in delivering solutions (25% weight), and experience with Microsoft stack (25% weight).
#
# 30. **Ongoing Technical Support**: Provide continuous support for the platform throughout the contract period.
#
# 31. **Regular Security Patching**: Implement regular security patching to maintain data confidentiality and integrity.
#
# 32. **Data Recovery and Backup Facilities**: Maintain facilities for data retention, disaster recovery, and backups.
#
# 33. **Audit History Management**: Develop functionality to track changes to records within the system.
#
# 34. **Yearly Instance Creation**: Enable creation of separate yearly instances for records without overriding previous versions.
#
# 35. **Management of Wage and Expense Allowances**: Users must manage wage and expense allowances, including search and navigation capabilities.
#
# 36. **Penalty Records Management**: Develop a system to manage penalty records linked to classifications.
#
# 37. **Rounding Functionality**: Implement rounding capabilities for formula results and allow editing of rounding rules.
#
# 38. **Document Metadata Management**: Include document metadata for flagging statuses and filtering documents.
#
# 39. **Template Management**: Users must manage templates, including uploading, replacing, and deleting.
#
# 40. **Determination Generation**: Users must generate determinations and related documents from the system.

# %% [markdown]
# ### **General Context for Company Profile**
# -----

# %%
print(rag_chain.extract_company_general_context())
# Out:
# **Company Background Summary:**
#
# AddAxis.AI is a leading artificial intelligence company with over seven years of experience in delivering AI solutions across Australia and the JAPAC region. The company specializes in transforming complex data into actionable insights, enabling organizations to leverage AI for agility, security, and innovation. With a team of over 20 AI researchers, data scientists, and engineers, AddAxis.AI has a strong track record of completing projects on time, within scope, and on budget.
#
# Proficient in various AI/ML platforms, including AWS, GCP, Azure, and OpenAI, the company particularly focuses on Google’s AI tools. Its expertise encompasses natural language processing, computer vision, reinforcement learning, and AI ethics, ensuring customized solutions that integrate seamlessly with clients' existing infrastructures. Recognized as one of the top ten machine learning companies in the Asia-Pacific region, AddAxis.AI is dedicated to making AI technology accessible and aligning it with tangible business outcomes, helping clients unlock new opportunities for innovation and growth.
#
# **Project Experience Summary:**
#
# 1. **Inventory Optimisation at Amazon.com**
#    - **Objective:** Identify and recover lost inventory worth millions.
#    - **Outcome:** Achieved significant innovation in inventory management.
#
# 2. **Integration of Golang with ChatGPT**
#    - **Objective:** Enhance system functionality through integration.
#    - **Technologies Used:** Golang, ChatGPT.
#
# 3. **WHMCS Integration**
#    - **Objective:** Streamline operational processes via integration.
#    - **Technologies Used:** WHMCS.
#
# 4. **WordPress Plugin Development**
#    - **Objective:** Create a custom plugin for WordPress.
#    - **Technologies Used:** WordPress.
#
# 5. **Architectural Design for IoT Company in Australia**
#    - **Objective:** Lead the design of IoT solutions.
#
# 6. **Solutions Development for Bureau of Meteorology using AI**
#    - **Objective:** Create AI-driven solutions for meteorological applications.
#    - **Technologies Used:** AI.
#
# The projects emphasize integration, development, and optimization across diverse technologies, with notable achievements in inventory management and AI solutions.
#
# **Product & Services Summary:**
#
# 1. **AI Solutions Design**: Comprehensive design of AI solutions that integrate seamlessly within existing ecosystems.
#
# 2. **Cloud AI Expertise**: Proficient in major cloud platforms including AWS (SageMaker, Bedrock), GCP (Vertex AI), and Microsoft AI.
#
# 3. **Data Warehousing**: Expertise in Snowflake, BigQuery, and Redshift for optimized data storage and retrieval.
#
# 4. **Reporting Tools**: Skilled in Microsoft Power BI, Google Looker, and AWS Quicksight for data reporting.
#
# 5. **Security and Reliability**: Focus on DevSecOps practices, utilizing infrastructure as code and GitOps for secure deployments.
#
# 6. **API Design and Management**: Development and management of APIs for AI integrations.
#
# 7. **MLOps (Machine Learning Operations)**: Integration and scalability of machine learning models, enhancing collaboration among data scientists, engineers, and operations teams.
#
# 8. **Serverless and Microservices Architectures**: Delivery of flexible, scalable solutions using containerization and serverless technologies, emphasizing:
#    - Improved fault isolation
#    - Faster deployment and development
#    - Enhanced maintainability
#    - Better alignment with business domains
#    - Resilience and reliability
#
# 9. **CAIO as a Service**: Provides strategic AI leadership and tailored AI solutions, offering access to a fractional Chief Artificial Intelligence Officer.
#
# 10. **Rapid AI Proof of Concept (RAPoC)**: Service to test the validity of AI ideation and deliver state-of-the-art AI projects.
#
# 11. **Audio Analysis**: Bespoke solutions using signal processing and machine learning to extract and interpret audio data.
#
# 12. **Computer Vision**: Advanced solutions utilizing computer vision technologies to enhance efficiency and security.
#
# 13. **Generative AI Applications**: Bespoke solutions using Generative AI and Large Language Models (LLMs) to enhance operational efficiency.
#
# 14. **Network Analysis**: Specializes in extracting insights from complex data relationships using advanced algorithms and machine learning techniques.
#
# 15. **Natural Language Processing (NLP)**: Comprehensive solutions to interpret, generate, and analyze text at scale, enhancing customer engagement and automating processes.
#
# **Key Benefits**:
# - Improved efficiency and reliability in software and ML model deployment.
# - Scalability and flexibility in application development.
# - Enhanced collaboration and transparency among teams.
# - Focus on ethical AI development and compliance with governance policies.
#
# **Customer Base**: Organizations across various sectors, including public and private sectors, startups, and those seeking to leverage AI for growth and innovation.
#
# **Pricing Models**: Not explicitly mentioned, but may include cost-efficient models based on resource usage.
#
# Overall, the company positions itself as a trusted partner in leveraging AI to transform industries and improve operational efficiency.
#
# ### Team Members Summary
#
# 1. **Dr. Alex Antic - Advisor**
#    - **Experience:** 18+ years in Advanced Analytics, Machine Learning, AI, Mathematics, and Statistics.
#    - **Domains:** Government, Asset Management, Insurance, Academia, Banking, Consulting.
#    - **Achievements:** Top 5 Analytics Leaders in Australia (IAPA, 2021).
#    - **Qualifications:** Ph.D. in Applied Mathematics, First Class Honours in Pure Mathematics, double degree in Mathematics and Computer Science.
#    - **Roles:** Senior advisory positions across various sectors.
#
# 2. **Mark Ridley - Advisor**
#    - **Experience:** Independent director and executive adviser with expertise in governance, risk, and ICT.
#    - **Current Roles:** Chair of audit & risk committees for the Department of Foreign Affairs and Trade and Australian Signals Directorate.
#    - **Responsibilities:** Overseeing financial and risk management.
#
# 3. **Timothy Scholes - Founder**
#    - **Role:** Founder responsible for technology solutions.
#    - **Experience:** Background in Macquarie Bank, Commbank, Qantas Insurance, AWS, and tech start-ups.
#    - **Skills:** Cloud computing, algorithms, data, machine learning, AI.
#    - **Qualifications:** M.Sc in Applied Mathematics, Executive MBA, B.Sc in pure mathematics and chemistry; Ph.D. candidate in Quantum Computing.
#
# 4. **Brett Dutton - Technical Product Lead**
#    - **Experience:** 30+ years in computer technology across Medical, Supply Chain, Payment Cards, and Telecommunications.
#    - **Responsibilities:** Managing data centres, training, and software product development.
#    - **Notable Achievements:** Innovated inventory optimisation at Amazon, integrated Golang with ChatGPT, led IoT architectural design, developed AI solutions for the Bureau of Meteorology.
#
# 5. **Genevieve Kelly - Informal Advisor**
#    - **Experience:** 14+ years in Google Product and GTM roles, focusing on product-led growth and partnerships.
#    - **Responsibilities:** Strategy, operations, and product management delivery.
#    - **Qualifications:** EMBA from Sydney University, BA in Media Production; currently pursuing a PhD in sustainability transitions and climate software startups.
#
# 6. **Luokun Gong - Technical Lead**
#    - **Experience:** Strong background in Audio Processing, Face Recognition, and Large Language Model projects.
#    - **Skills:** Software Development Management and problem-solving.
#    - **Responsibilities:** Navigating complex projects and delivering software development results.
#
# This team combines extensive experience in analytics, governance, technology, and product management, positioning the company for success across various sectors.

# %% [markdown]
# ### **Query Answering**
# -----

# %% [markdown]
# #### **Query 1**

# %%
print(rag_chain.query_answering("How to perform cybersecurity?"))
# Out:
# To effectively perform cybersecurity, particularly in the context of the Fair Work Commission's (FWC) requirements and AddAxis.AI's capabilities, the following comprehensive approach should be adopted:
#
# ### 1. **Compliance with Legal and Regulatory Requirements**
#    - Ensure adherence to the **Privacy Act 1988** and **Australian Privacy Principles** as mandated by the FWC. This includes implementing policies and practices that protect personal data and ensure transparency in data handling.
#
# ### 2. **Security Framework Implementation**
#    - Adopt the **Australian Government Information Security Manual (ISM)** to guide the development and implementation of security measures. This includes establishing a security posture that aligns with the FWC's policies and procedures.
#
# ### 3. **Role-Based Access Control (RBAC)**
#    - Implement **configurable RBAC** to ensure that access to sensitive information is granted based on the principle of **least privilege**. This allows the FWC to regulate user access according to their roles and responsibilities, enhancing security and minimizing risks.
#
# ### 4. **Data Encryption**
#    - Utilize **encryption in transit** and **encryption at rest** using **ASD Approved Cryptographic Protocols** and **Algorithms**. This ensures that sensitive data is protected from unauthorized access during transmission and while stored.
#
# ### 5. **Monitoring and Logging**
#    - Establish robust **monitoring and logging** mechanisms to track user activities and maintain logs of key events for audit purposes. This includes logging actions such as record creation, updates, deletions, and unauthorized access attempts.
#
# ### 6. **Regular Security Patching**
#    - Implement a strategy for **regular security patching** to maintain the confidentiality, integrity, and availability of data. This includes timely updates to software and systems to protect against vulnerabilities.
#
# ### 7. **Incident Response and Recovery**
#    - Develop a clear **Incident Response Plan** that outlines procedures for responding to cybersecurity events. This should include defined **Service Level Agreements (SLAs)** for response times and recovery processes, ensuring that the FWC can quickly address and mitigate any security incidents.
#
# ### 8. **User Training and Awareness**
#    - Conduct regular training sessions for staff to raise awareness about cybersecurity best practices, including recognizing phishing attempts and understanding the importance of data protection.
#
# ### 9. **Utilization of Advanced Technologies**
#    - Leverage AddAxis.AI's expertise in **AI-driven security solutions** to enhance threat detection and response capabilities. This includes using machine learning algorithms to identify anomalies and potential security breaches in real-time.
#
# ### 10. **Audit and Compliance Checks**
#    - Regularly perform **audits** to ensure compliance with security policies and procedures. This includes reviewing access logs, security configurations, and incident response effectiveness.
#
# ### 11. **Collaboration with Security Teams**
#    - Work closely with the FWC's Change Advisory Board (CAB) to ensure that all security measures align with organizational goals and that any proposed changes are evaluated for security implications.
#
# ### 12. **Federated Authentication**
#    - Implement **federated authentication** to enable Single Sign-On (SSO) capabilities, allowing users to access multiple systems securely with a single set of credentials.
#
# ### Conclusion
# By integrating these cybersecurity practices, AddAxis.AI can ensure a robust security posture that meets the FWC's requirements while leveraging its expertise in AI and cloud technologies. This approach not only enhances security but also fosters trust and compliance, ultimately supporting the FWC's mission to manage wage rates and awards effectively.

# %% [markdown]
# #### **Query 2**

# %%
print(rag_chain.query_answering("What is the deadline for the bid?"))
# Out:
# The deadline for the bid is September 4th, 2024.
#
# At AddAxis.AI, we are committed to delivering innovative AI solutions that align with the needs outlined in the RFP. Our extensive experience in developing user-friendly systems, particularly in document management and data integration, positions us well to meet the Fair Work Commission's objectives. We look forward to the opportunity to leverage our expertise in Microsoft technologies and our proven track record in project delivery to create a robust and efficient platform for managing award updates and document generation.

# %% [markdown]
# #### **Query 3**

# %%
print(rag_chain.query_answering("How will the base architecture be implemented using the Microsoft 365 Stack and Dynamics 365, and what are the key considerations for this integration?"))
# Out:
# To implement the base architecture using the Microsoft 365 Stack and Dynamics 365 for the Fair Work Commission's Modern Awards Database project, AddAxis.AI will leverage its extensive experience in AI solutions and cloud technologies, particularly focusing on Microsoft products. The implementation will be structured around the following key considerations:
#
# ### Implementation Strategy
#
# 1. **Modular Architecture**:
#    - Develop the system in a modular fashion, allowing components to be reused across different applications and services. This aligns with the RFP's requirement for modularity (REQ-033) and ensures scalability and flexibility in future enhancements.
#
# 2. **Integration with Microsoft 365 and Dynamics 365**:
#    - Utilize Microsoft Power Platform tools (Power Apps, Power Automate, and Power BI) to create user-friendly interfaces for document management, data validation, and reporting. This will facilitate easy access and manipulation of award data without extensive programming knowledge.
#    - Implement Dynamics 365 for managing workflows, customer engagement, and data storage, ensuring seamless integration with existing services, particularly the MAPD API.
#
# 3. **Document Management System**:
#    - Establish a robust document management system that aligns with Enterprise Document Management standards (REQ-034). This will include secure storage of award documents, metadata management, and lifecycle tracking of documents, ensuring compliance with privacy and security standards.
#
# 4. **Data Validation and Formula Library**:
#    - Create a formula library within the Dynamics 365 environment to manage and calculate pay rates efficiently. This library will support the RFP's requirement for accurate data validation and calculations, ensuring that all wage rates and allowances are correctly processed.
#
# 5. **User-Friendly Templating Solution**:
#    - Develop a templating solution that allows users to modify award templates without coding skills. This will be achieved through Power Apps, enabling staff to generate Word documents populated with data from the database easily.
#
# 6. **Centralized Repository**:
#    - Implement a centralized repository for managing Award Pay Rates, formulas, and historical data. This will facilitate easy retrieval and management of previous award rates, supporting the RFP's objectives for data import/export functionality.
#
# 7. **Security and Compliance**:
#    - Ensure that the architecture adheres to the Australian Government Information Security Manual and complies with the Privacy Act 1988. Regular security patching and data recovery facilities will be established to maintain data integrity and confidentiality.
#
# 8. **Ongoing Support and Training**:
#    - Provide continuous support and training for Fair Work Commission staff to ensure effective use of the new system. This includes developing documentation, User Acceptance Testing scripts, and knowledge articles to facilitate smooth transitions.
#
# 9. **Regular Status Updates**:
#    - Establish a single point of contact for project management, ensuring regular status updates and reports are communicated to the Project Sponsor, Program Manager, and key stakeholders, as outlined in the RFP.
#
# ### Key Considerations for Integration
#
# - **Compatibility**: Ensure full compatibility with the Fair Work Commission’s standard operating environment, focusing on reusable elements within the Microsoft ecosystem.
# - **User Experience**: Prioritize user-friendly interfaces and tools that minimize the need for programming knowledge, enhancing accessibility for all staff members.
# - **Version Control**: Implement effective version control mechanisms to keep template documents current and maintain historical integrity.
# - **Audit Trails**: Develop functionality to track changes and maintain an audit history for all records, ensuring transparency and accountability.
# - **Timely Delivery**: Adhere to designated timeframes and milestones within the fixed cost budget, ensuring compliance with all project requirements.
#
# By leveraging AddAxis.AI's expertise in AI solutions, cloud technologies, and Microsoft products, the implementation of the base architecture will not only meet the Fair Work Commission's needs but also enhance operational efficiency and user satisfaction.

# %% [markdown]
# #### **Query 4**

# %%
print(rag_chain.query_answering("What mechanisms will be in place for monitoring user activity and maintaining logs of key events for audit purposes?"))
# Out:
# To ensure robust monitoring of user activity and maintain logs of key events for audit purposes, AddAxis.AI will implement a comprehensive auditing framework as part of the proposed solution for the Fair Work Commission's Modern Awards Database. This framework will include the following mechanisms:
#
# 1. **User Activity Monitoring**: The system will track all user interactions, including logins, data access, and modifications. This will provide a clear record of who accessed the system and what actions were taken.
#
# 2. **Audit Logs**: Detailed logs will be maintained for key events, including:
#    - Creation, modification, and deletion of records.
#    - Changes to formulas and formula instances, capturing before and after values.
#    - Unauthorized access attempts, including date, time, and user identification.
#
# 3. **Change History**: Users will have the ability to view an audit history of changes made to records within the system. This includes:
#    - A comprehensive log of all actions performed by users, ensuring transparency and accountability.
#    - Specific records for add/modify/create actions related to formulas, allowing for easy tracking of changes.
#
# 4. **Real-Time Monitoring**: The system will support real-time monitoring capabilities, enabling administrators to oversee user activities as they occur. This will facilitate immediate responses to any suspicious activities.
#
# 5. **Compliance with Standards**: The auditing mechanisms will adhere to the Australian Government Information Security Manual and the Privacy Act 1988, ensuring that all data handling and logging practices meet regulatory requirements.
#
# 6. **Reporting and Alerts**: The system will include features for generating reports on user activity and audit logs, as well as alerting administrators to any anomalies or unauthorized access attempts.
#
# 7. **User-Friendly Interface**: The audit capabilities will be integrated into a user-friendly dashboard, allowing Commission staff to easily access and review audit logs without extensive technical knowledge.
#
# By leveraging AddAxis.AI's expertise in AI solutions and cloud technologies, particularly within Microsoft’s product suite, we will ensure that the auditing framework is not only effective but also seamlessly integrated into the overall system architecture. This approach will enhance the Fair Work Commission's ability to maintain compliance, ensure data integrity, and support ongoing operational needs.

# %% [markdown]
# ### **Question Extraction**
# ------

# %%
for question in rag_chain.retrieve_question_without_question_mark():
    print(question)
# Out:
# What reporting capabilities will be available for tracking template usage and modifications?
# What encryption algorithms will be employed to ensure information is encrypted at rest, and how will compliance with ASD Approved Cryptographic Algorithms be maintained?
# How will the project management be structured to utilize the Commission’s MS Teams instance effectively?
# How will the linkage between wage allowances and classification rates be maintained, and what processes will ensure that changes to classification rates automatically recalculate the associated wage allowances?
# What factors does the expert panel of the Fair Work Commission consider when determining the annual wage review increases?
# Can you provide details on the specific fields that will require fixed identification numbers, and how will these be managed within the system?
# What capabilities should the document templating solution have to allow non-technical staff to modify Modern Award templates easily?
# What optimizations will be made to achieve response times within 1 second and sub-second initial load times?
# How are penalty rates calculated in relation to classification base rates and overtime percentages?
# How will the seller ensure effective communication and status reporting with the Commission’s Project Manager?
# What action processes will be included in the system, and how will these processes be detailed and validated during the discovery sessions?
# What capabilities will the reporting feature include, particularly regarding user-configurable reports and export formats?
# What processes will be in place to collaborate with the Commission’s Change Advisory Board (CAB) for timely proposal submissions?
# How will the system ensure compliance with the specified global style for expense allowances?
# What is the relationship between calculated base rates and the rates for apprentices and juniors?
# How do expense allowance rates interact with calculated and calculated base rates in wage determinations?
# What specific capabilities and personnel does your organization have that align with the Fair Work Commission's MAP System Development requirements?
# How will the system facilitate the management of global properties for templates, particularly regarding the addition and removal of member names?
# What specific functionalities will the system provide to allow users to increase rates across all awards or individual rates in a single award?
# What is the vendor's capability in understanding payroll calculations and formulas, and how will this be demonstrated?
# What specific formulas and rounding rules will be implemented to allow for individual or bulk increases of rates in the classifications record?
# What specific insights are expected regarding environments, constraints, and standard operating procedures?
# What are the detailed requirements for the management of calculation formulas for classifications, wage allowances, expense allowances, and penalty records?
# How do wage allowance rates relate to the standard rate defined in modern awards?
# What are the specific requirements for the MAP System to support the Fair Work Commission's functions?
# What specific measures will be implemented to comply with the Essential Eight strategies for cybersecurity as promoted by the Australian Signals Directorate (ASD)?
# What strategies will be implemented to address the "should have" and "nice to have" requirements, particularly in relation to Data and Leadership?
# How will the homepage of the MAPD be designed to present users with a comprehensive list of awards, and what specific data fields will be included?
# What features will be implemented to manage staged increases with different commencement dates, and how will users select an operative from date for the AWR change?
# What features will be included to enable general staff to create, edit, and update document templates without requiring coding skills?
# What specific deliverables will be provided to meet the requirements outlined in the proposal?
# What is the timeline for providing feedback and approval on documentation?
# What mechanisms will be implemented to allow users to easily edit penalties and select appropriate formulas, including entering rounding rules?
# What mechanisms will be in place for monitoring user activity and maintaining logs of key events for audit purposes?
# What formula will be used to calculate the expense allowances, and how will it accommodate lookups for other expense-related allowances?
# Can you provide detailed information on how your proposal addresses the non-functional requirements outlined in the MAP System Development documentation?
# How will the MAP System manage the lifecycle of all document templates, including tagging to indicate the current stage?
# How will the search functionality for Penalties be implemented to ensure users can efficiently find information based on Classification, Clauses, or Penalty description?
# What are the specific functional requirements for Import/Export, Integration, Processes, Reporting, and Validation in the project?
# How will the system handle the management of reference data for expense allowances and CPI data independently of the AWR decision?
# What are the potential impacts of the Annual Wage Review Decision on the minimum rates in Modern Awards?
# What strategies can be implemented to ensure data validation and accuracy in the calculations of award rates?
# Can you confirm that all prices will be quoted in Australian dollars and inclusive of GST?
# How will the system ensure accurate calculations of rates in accordance with the Decision, including handling no change, percentage increases, dollar increases, or a combination of both?
# What are the expected capabilities and limitations of the proposed solution architecture?
# How will the proposed solution ensure compliance with all Australian legal and regulatory requirements?
# What user-friendly solutions can be implemented to enhance the existing platform for generating award documents?
# How will the role-based access controls be configured to regulate users’ and administrators’ access to information and system functionality?
# How will the system handle version control for replacement templates?
# What mechanisms will be in place to ensure that rounding rules only apply to the current year's data while allowing for re-rounding of previous year's data if rules change?
# How will the system facilitate filtering and sorting of search results across various data columns, and what options will be available for users?
# How will the system ensure that expense allowances are automatically adjusted based on changes in the Consumer Price Index (CPI) values?
# What is your Microsoft Partner level and what capabilities do you possess?
# What specific features will be included in the comprehensive search capability to ensure it meets user needs for querying by string, dates, allowance information, and ID numbers?
# How will the integration with existing services like PowerBI and the external API (mapAPI) be implemented and managed?
# How will users be able to create, edit, and delete formulas in the Formula Library, and what user interface will support this functionality?
# What specific file formats will be supported for uploading templates in the system?
# How are calculated base rates determined and what factors influence their adjustment?
# What are the expected outcomes or impacts of each type of increase on overall wage structures?
# How can the adjustment of over 70,000 unique wage-related rates and allowances be effectively managed following the Annual Wage Review?
# What process will be implemented to allow users to finalize the AWR year, and how will the system ensure that figures are locked down post-finalization?
# Can you provide more details on the user roles and permissions related to generating determinations of awards?
# Who are the key personnel assigned to the project, and what are their specific areas of expertise?
# How will existing data be imported into the new system, and what challenges might arise during this process?
# How will users be able to manage Expense Allowances and associated information effectively within the system?
# How will the system ensure compliance with the AWR decision and any related regulations?
# How are expense allowance rates adjusted based on movements in the Consumer Price Index (CPI)?
# What specific support SLAs are required for each of the Commission’s locations?
# How will the search functionality for Expense Allowances be implemented, and what are the expected user interactions?
# What specific user interface features are required for admin level users to record the AWR decision?
# What encryption protocols will be used to ensure information is encrypted in transit, and how will compliance with ASD Approved Cryptographic Protocols be achieved?
# What specific allowances will be included in the calculation of employees' ordinary hourly rates?
# How will the seller ensure that all resources provided have the appropriate levels of experience?
# What industry-standard security mechanisms will be supported for data transmission?
# How will the system ensure that document templates can effectively utilize all relevant data for generating wage determinations, expense determinations, and awards?
# What data retention, disaster recovery, and backup solutions will the platform offer?
# What support SLAs will be provided for each of the Commission’s locations, and how will they be structured?
# What current architecture documentation is required for existing services?
# Do you comply with the Privacy Act 1988 and Australian Privacy Principles, and how do you meet this requirement?
# Who will be responsible for maintaining the project log, and how will communication be managed between the Project Manager and Project Sponsor?
# Can you describe the audit capability that will be available for all system and business functions, including the specifics of logging and tracking changes to records?
# What is the process for adjusting expense allowance rates based on movements in the Consumer Price Index (CPI)?
# What strategies will be implemented to meet designated timeframes and agreed milestones within the fixed cost budget?
# Can you confirm that your resourcing consists of fully Australian-based staff?
# What mechanisms will be implemented to create and maintain separate yearly instances of awards without overriding previous versions?
# What measures will be taken to host the solution within Australia and comply with Australian legal jurisdiction?
# What examples of previous implementations can the vendor provide to demonstrate their capability to meet the requirements?
# How will the ongoing support plan address unplanned outages, feature enhancements, and scheduled maintenance?
# How are expense allowance rates adjusted based on movements in the Consumer Price Index (CPI), and what factors influence these adjustments?
# How does your organisation have the capabilities to meet the evaluation criteria through experience and key personnel?
# How will the system handle the application of staged increases, and what parameters will users need to input?
# What features will be included to facilitate the export of classifications, allowances, and penalties data, and how will this process be streamlined for users?
# What specific user interface elements will be implemented to allow users to create and edit calculated rates based on the classification base rate?
# How will the MAP System facilitate the Annual Wage Review process conducted by the Commission's Expert Panel?
# What mechanisms will be in place to allow users to access and revert to previous versions of a template?
# What is your experience with the Microsoft stack, particularly with Office 365, Dynamics, Dataverse, and Power Platform?
# How will the document templating solution be designed to ensure ease of modification without requiring coding or specialized skills?
# What support model will be provided to ensure full continuity of services for the developed solution post-transition?
# How will users be able to manage classifications and wage allowances, and what functionalities will be available for creating calculated base rates?
# How will the project ensure compliance with the mandatory requirements related to Architecture and Data?
# How will the system ensure that the classifications record accurately reflects the rates contained in each award, and what mechanisms will be in place for adjustments based on decisions or the Annual Wage Review?
# What criteria will determine the exceptional circumstances option for wage increases?
# What mechanisms will be in place to allow users to update the status of documents throughout the award lifecycle?
# What process will be in place to create a new version of a record upon updates, while ensuring that the version number remains unchanged if there are no changes to dollar figures?
# What ongoing support and update mechanisms will be in place for the proposed solution during the Contract term?
# How can the formula library be designed to ensure accurate calculations of rates of pay for each Award?
# What mechanisms will be in place for providing regular status updates and reports to key stakeholders?
# What specific features should be included in the document management system to effectively manage the lifecycle of documents and related data?
# What business continuity arrangements will be implemented in response to the COVID-19 pandemic for the delivery of this project?
# What audit mechanisms will be implemented to track changes to formulas and formula instances within the system?
# How will ongoing support and a recovery process from a cyber security event be structured, including SLAs and Incident Response Plans?
# Can you provide examples of previous projects where you have successfully delivered solutions using the same technologies proposed?
# What are the implications of a percentage increase versus a real dollar increase in minimum wages for employees?
# How will the solution ensure that documents are discoverable within one minute of being published?
# What mechanisms will be in place to allow users to override the default operative from and operative to dates when managing penalties?
# What is your demonstrable experience with the Microsoft stack, including Office 365, Dynamics, Dataverse, and Power Platform?
# How will the system ensure the integrity and accessibility of the audit history for changes made to formulas and formula instances?
# What specific security posture, policies, and procedures must be adhered to in the project?
# How will the solution handle approximately 30 simultaneous users or logins effectively?
# What measures will the vendor implement to secure privileged access to FWC resources?
# What security measures will be implemented to ensure the integrity of the stored templating source code documents?
# What criteria determine whether an allowance amount remains the same despite changes in the CPI?
# What specific functionalities are required for managing Wage Allowances and their associated information?
# How do ordinary hourly rates incorporate allowances, and what is the impact on penalty rates?
# Will the quoted prices remain fixed during the validity period of the quote?
# What specific processes will be implemented to ensure the finalisation of the AWR year, including the insertion of the operative to date?
# How can we streamline the current system for updating rates in Awards to reduce the reliance on programming knowledge?
# What is the process for importing and exporting data related to templates and determinations?
# What are the expectations for the development and maintenance of as-built documentation, UAT scripts, and knowledge articles?
# What specific experience does your organization have that relates to the project brief?
# How are calculated base rates for apprentices and juniors established in relation to adult classifications?
# Can you provide technical guidance on potential future solutions that can streamline the template creation process for the 150 distinct awards?
# What is the significance of linking penalty clauses to classification clauses in wage awards?
# What is the process for assigning unique Requirement IDs, and how will they be tracked throughout the project life-cycle?
# How will the annual wage review (AWR) be conducted and what factors will be considered?
# What detailed system and implementation documentation will be provided to support the platform's design and operations?
# How does your organization ensure that all quoted prices include taxes, duties, and government charges?
# What measures will be taken to ensure the secure storage of all award documents within the core system, and how will the system align with Enterprise Document Management capabilities?
# What specific environments need to be established within the tenancies, and what are the requirements for these environments?
# How can we ensure the integration of additional services and systems with the core MAPD system is maintained effectively?
# What are the requirements for vendor presentations to the Commission’s Executive Team?
# What are your business continuity arrangements in response to the COVID-19 pandemic relevant to the delivery of this project?
# How will the penalty record system be designed to ensure that changes in classification rates automatically recalculate the corresponding penalty rates?
# How will the new system facilitate the import and export of data related to Awards and Determinations?
# How will the solution support FWC's Internet Security policies for both staff and customers?
# Can you confirm that your resourcing is fully available to begin the project in September 2024?
# How will weekly standups be coordinated, and what topics should be covered?
# What ongoing training and support arrangements will be provided, including the types of training materials and courses available during the contract period?
# How frequently will the vendor perform security patching to maintain the confidentiality, integrity, and availability of FWC data?
# How will non-functional requirements such as Delivery, Development/Version Control, Performance, Security, and Usability be prioritized and managed throughout the project?
# How will the proposed solution comply with ASD's Blueprint for Secure Cloud?
# What measures will be taken to adhere to the Australian Government Information Security Manual (ISM) in the proposed solution?
# What are the detailed business requirements that will form the basis of user acceptance criteria, and how will they be gathered?
# What role-based access control mechanisms will be implemented to ensure segregation of duties and least privilege access?
# How will the proposed technical solution ensure compliance with the Privacy Act 1988 and Australian Privacy Principles?
# How will the solution ensure 24/7 availability with 99.99% uptime?
# What features should the MAP System include to effectively manage and regulate the 155 modern awards in Australia?
# Can you provide examples of how the tiered increase functionality will work in practice?
# What steps are involved in the 3rd party onboarding process to ensure vendor resources have adequate access to the environment?
# How will the system ensure that rounding rules can be applied to individual rate calculations without affecting finalized figures from previous years?
# How does your organization plan to meet the functional requirements for the core system, formula library, and templating aspects of the MAP System?
# How will the system ensure that penalty formula records accurately capture all mandatory fields such as Clause ID, penalty description, rate, rate unit, formula, and rounding rule?
# Can the vendor provide evidence of relevant security certifications, such as IRAP or ISO?
# How will the recalculation sequence for base rates and associated rates be implemented and validated?
# What discounts have been applied to your pricing, and how are they justified?
# How do all-purpose allowances impact the calculation of ordinary hourly rates and associated penalties or entitlements for employees?
# What is the process for coordinating access to key stakeholders and scheduling workshops and cadence meetings?
# How can the integration of Microsoft’s product suites enhance the overall functionality and user experience of the new system?
# What processes will be implemented for users to upload, replace, and delete templates within the system?
# What specific functionalities and features are required for the formula library to effectively store and calculate rates of pay for each Award?
# What specific requirements are outlined in the RFQ that we need to meet to ensure a successful proposal?
# How will the base architecture be implemented using the Microsoft 365 Stack and Dynamics 365, and what are the key considerations for this integration?
# What strategies will be implemented to meet the pre-defined response times for different functions?
# What factors does the expert panel of the Fair Work Commission consider when determining the annual wage review increase?
# What is the process for submitting proposals to the Change Advisory Board (CAB), and what are the timelines for approval?
# Are there any anticipated travel costs associated with the project, and how will they be accounted for in the pricing?
# How will the system ensure that the classifications record accurately reflects the rates contained in each award, and what processes will be used to implement adjustments based on decisions or the Annual Wage Review?
# What measures can be taken to ensure the security and integrity of the data stored in the new platform?
# Can the vendor confirm their capability, skills, and ability to execute on the requirements?
# What is the process for invoice approval, and what are the implications of payment timelines?
# How will your organisation deliver the requirements outlined in the MAP System Development documentation?
# Can you detail the approach for federating to FWC's Authentication and Authorisation capability to maintain a single customer identity across all systems for SSO?
# What mechanisms will be in place to manage document metadata, properties, and history, and how will bulk updates be handled within the system?
# What process will be used to upload a CSV of print numbers, and how will the system ensure accurate matching to award codes?
# How will weekly updates be structured and what specific information should be included in these reports?
# What strategies can be implemented to ensure timely preparation and publication of draft and final determinations and updated awards?
# How will the system ensure that the calculated rates are accurately derived from the base rates and comply with the AWR decision?
# What strategies will be employed to ensure that additional components and features are developed in a modular way, and how will microservices architectures be utilized?
# Can you provide details on the recovery processes in place to demonstrate resilience from outages?
# What mechanisms will be in place to allow users to search and filter wage allowance records effectively by allowance description, payment frequency, and clause ID?
# What existing business processes and requirements need to be provided during the Discovery phase?
# What facilities will be maintained for data retention, disaster recovery, and data back-ups and restoration?
# How will the adjustment of expense allowances be automated in accordance with CPI figures, and what formula will be used for this adjustment?
# How does the standard rate serve as a reference for wage-related allowances, and what are the implications for employees at different classification levels?
# Are you able to engage under the Digital Marketplace Head Agreement SON3413842, and how do you meet this requirement?
# What demonstrable success does your organisation have in delivering solutions that utilise the same technologies proposed?
# How will the solution ensure compliance with all Australian legal and regulatory requirements?
# How will the vendor verify that the requirements have been completed satisfactorily?
# How can the reimagined platform better meet the needs of the Fair Work Commission in terms of document management and data validation?
# What are the estimated costs for research participant reimbursement, including recruitment fees?
# How does the base rate for minimum wages vary across different modern awards?
# What ongoing technical support will the vendor provide during the contract period?
# What is the impact of including allowances in the ordinary hourly rates on the calculation of penalty rates?
# What ongoing training and support arrangements will be provided, including training materials and courses?
